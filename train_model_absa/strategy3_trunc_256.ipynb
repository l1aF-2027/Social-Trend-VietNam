# %%
import json
import pandas as pd
from tqdm import tqdm
from sklearn.preprocessing import LabelEncoder
from sklearn.metrics import f1_score

from transformers import AutoTokenizer, AutoModel
import torch
import torch.nn.functional as F
from torch.nn.utils.rnn import pad_sequence

from sklearn.model_selection import train_test_split
import torch.nn as nn
from torch.utils.data import DataLoader, TensorDataset
import torch.optim as optim
from torch.optim.lr_scheduler import StepLR

# %%
# !pip install einops
# Out:
# Requirement already satisfied: einops in /usr/local/lib/python3.11/dist-packages (0.8.1)

# %%
with open('/kaggle/input/data-ds200/data_labeled_soft_cleaned.json', 'r', encoding='utf-8') as f:
    raw_data = json.load(f)

def build_text(item):
    parts = [item.get("post_content", "")]
    if 'comment' in item:
        parts += item['comment'].get('parent_comment_texts', [])
        if item['comment'].get('comment_text'):
            parts.append(item['comment']['comment_text'])
    img_descs = [desc['image_description'] for desc in item.get("image_descriptions", [])]
    parts += img_descs
    return "\n".join(parts)

# %%
data = []
for item in raw_data:
    text = build_text(item)
    aspects = [item.get("Aspect_1", "Other"), item.get("Aspect_2") or "null"]
    sentiments = item.get("Sentiment", ["null", "null"])
    data.append({
        "text": text,
        "aspect_1": aspects[0],
        "aspect_2": aspects[1],
        "sentiment_1": sentiments[0],
        "sentiment_2": sentiments[1] if aspects[1] != "null" else "null"
    })

# %%
df = pd.DataFrame(data)
df.head()
# Out:
#                                                 text aspect_1 aspect_2  \
# 0  TÒA ĐÃ TUYÊN PHẠT BỐ RUỘT 6 NĂM TÙ   Bị cáo và...      Law    Other
# 1  TÒA ĐÃ TUYÊN PHẠT BỐ RUỘT 6 NĂM TÙ   Bị cáo và...      Law    Other
# 2  TÒA ĐÃ TUYÊN PHẠT BỐ RUỘT 6 NĂM TÙ   Bị cáo và...      Law   Health
# 3  TÒA ĐÃ TUYÊN PHẠT BỐ RUỘT 6 NĂM TÙ   Bị cáo và...      Law   Health
# 4  TÒA ĐÃ TUYÊN PHẠT BỐ RUỘT 6 NĂM TÙ   Bị cáo và...      Law    Other
#
#   sentiment_1 sentiment_2
# 0    negative    negative
# 1    negative    negative
# 2    negative    negative
# 3    negative    negative
# 4    negative    negative

# %%
all_aspects = pd.concat([df['aspect_1'], df['aspect_2']]).unique()
aspect_encoder = LabelEncoder()
aspect_encoder.fit(all_aspects)

df['aspect_1_enc'] = aspect_encoder.transform(df['aspect_1'])
df['aspect_2_enc'] = aspect_encoder.transform(df['aspect_2'])

# %%
print(aspect_encoder.classes_)
# Out:
# ['Art' 'Fashion' 'Food' 'Health' 'Law' 'Other' 'Sport' 'null']

# %%
# sentiment_map = {"positive": 1.0, "neutral": 0.0, "negative": -1.0}
# df["sentiment_1_score"] = df["sentiment_1"].map(sentiment_map)
# df["sentiment_2_score"] = df["sentiment_2"].map(sentiment_map)

# %%
all_aspects = pd.concat([df['sentiment_1'], df['sentiment_2']]).unique()
sentiment_encoder = LabelEncoder()
sentiment_encoder.fit(all_aspects)

df['sentiment_1_enc'] = sentiment_encoder.transform(df['sentiment_1'])
df['sentiment_2_enc'] = sentiment_encoder.transform(df['sentiment_2'])

# %%
print(sentiment_encoder.classes_)
# Out:
# ['negative' 'neutral' 'null' 'positive']

# %%
from collections import Counter
import numpy as np
import torch

def compute_class_weights(name, combined_labels):
    counts = Counter(combined_labels)
    total = sum(counts.values())
    print(f"\n{name} distribution:")
    for k, v in sorted(counts.items()):
        print(f"  Class {k}: {v} ({v/total:.2%})")

    num_classes = len(counts)
    weights = [total / (num_classes * counts[i]) for i in range(num_classes)]
    print(f"{name} weights: {np.round(weights, 3)}")
    return torch.tensor(weights, dtype=torch.float32)

# %%
# Gộp nhãn aspect
combined_aspect = pd.concat([df["aspect_1_enc"], df["aspect_2_enc"]]).tolist()
w_aspect = compute_class_weights("Aspect", combined_aspect)

# Gộp nhãn sentiment
combined_sentiment = pd.concat([df["sentiment_1_enc"], df["sentiment_2_enc"]]).tolist()
w_sentiment = compute_class_weights("Sentiment", combined_sentiment)
# Out:
# Aspect distribution:
#   Class 0: 579 (4.85%)
#   Class 1: 344 (2.88%)
#   Class 2: 809 (6.77%)
#   Class 3: 1894 (15.86%)
#   Class 4: 2399 (20.09%)
#   Class 5: 3294 (27.58%)
#   Class 6: 624 (5.22%)
#   Class 7: 2001 (16.75%)
# Aspect weights: [2.579 4.34  1.845 0.788 0.622 0.453 2.393 0.746]
#
# Sentiment distribution:
#   Class 0: 6488 (54.32%)
#   Class 1: 885 (7.41%)
#   Class 2: 2001 (16.75%)
#   Class 3: 2570 (21.52%)
# Sentiment weights: [0.46  3.374 1.492 1.162]

# %%
df.head()
# Out:
#                                                 text aspect_1 aspect_2  \
# 0  TÒA ĐÃ TUYÊN PHẠT BỐ RUỘT 6 NĂM TÙ   Bị cáo và...      Law    Other
# 1  TÒA ĐÃ TUYÊN PHẠT BỐ RUỘT 6 NĂM TÙ   Bị cáo và...      Law    Other
# 2  TÒA ĐÃ TUYÊN PHẠT BỐ RUỘT 6 NĂM TÙ   Bị cáo và...      Law   Health
# 3  TÒA ĐÃ TUYÊN PHẠT BỐ RUỘT 6 NĂM TÙ   Bị cáo và...      Law   Health
# 4  TÒA ĐÃ TUYÊN PHẠT BỐ RUỘT 6 NĂM TÙ   Bị cáo và...      Law    Other
#
#   sentiment_1 sentiment_2  aspect_1_enc  aspect_2_enc  sentiment_1_enc  \
# 0    negative    negative             4             5                0
# 1    negative    negative             4             5                0
# 2    negative    negative             4             3                0
# 3    negative    negative             4             3                0
# 4    negative    negative             4             5                0
#
#    sentiment_2_enc
# 0                0
# 1                0
# 2                0
# 3                0
# 4                0

# %%
tokenizer = AutoTokenizer.from_pretrained("jinaai/jina-embeddings-v3")  # Tokenizer for Jina embeddings
model_token = AutoModel.from_pretrained("jinaai/jina-embeddings-v3", 
                                                   trust_remote_code=True,
                                                   torch_dtype=torch.float32)
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
model_token.to(device)
model_token.eval()
# Out:
# tokenizer_config.json: 0.00B [00:00, ?B/s]
# tokenizer.json:   0%|          | 0.00/17.1M [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/964 [00:00<?, ?B/s]
# config.json: 0.00B [00:00, ?B/s]
# configuration_xlm_roberta.py: 0.00B [00:00, ?B/s]
# A new version of the following files was downloaded from https://huggingface.co/jinaai/xlm-roberta-flash-implementation:
# - configuration_xlm_roberta.py
# . Make sure to double-check they do not contain any added malicious code. To avoid downloading new versions of the code file, you can pin a revision.
# modeling_lora.py: 0.00B [00:00, ?B/s]
# modeling_xlm_roberta.py: 0.00B [00:00, ?B/s]
# embedding.py: 0.00B [00:00, ?B/s]
# A new version of the following files was downloaded from https://huggingface.co/jinaai/xlm-roberta-flash-implementation:
# - embedding.py
# . Make sure to double-check they do not contain any added malicious code. To avoid downloading new versions of the code file, you can pin a revision.
# rotary.py: 0.00B [00:00, ?B/s]
# A new version of the following files was downloaded from https://huggingface.co/jinaai/xlm-roberta-flash-implementation:
# - rotary.py
# . Make sure to double-check they do not contain any added malicious code. To avoid downloading new versions of the code file, you can pin a revision.
# mlp.py: 0.00B [00:00, ?B/s]
# A new version of the following files was downloaded from https://huggingface.co/jinaai/xlm-roberta-flash-implementation:
# - mlp.py
# . Make sure to double-check they do not contain any added malicious code. To avoid downloading new versions of the code file, you can pin a revision.
# xlm_padding.py: 0.00B [00:00, ?B/s]
# A new version of the following files was downloaded from https://huggingface.co/jinaai/xlm-roberta-flash-implementation:
# - xlm_padding.py
# . Make sure to double-check they do not contain any added malicious code. To avoid downloading new versions of the code file, you can pin a revision.
# mha.py: 0.00B [00:00, ?B/s]
# A new version of the following files was downloaded from https://huggingface.co/jinaai/xlm-roberta-flash-implementation:
# - mha.py
# . Make sure to double-check they do not contain any added malicious code. To avoid downloading new versions of the code file, you can pin a revision.
# block.py: 0.00B [00:00, ?B/s]
# stochastic_depth.py: 0.00B [00:00, ?B/s]
# A new version of the following files was downloaded from https://huggingface.co/jinaai/xlm-roberta-flash-implementation:
# - stochastic_depth.py
# . Make sure to double-check they do not contain any added malicious code. To avoid downloading new versions of the code file, you can pin a revision.
# A new version of the following files was downloaded from https://huggingface.co/jinaai/xlm-roberta-flash-implementation:
# - block.py
# - stochastic_depth.py
# . Make sure to double-check they do not contain any added malicious code. To avoid downloading new versions of the code file, you can pin a revision.
# A new version of the following files was downloaded from https://huggingface.co/jinaai/xlm-roberta-flash-implementation:
# - modeling_xlm_roberta.py
# - embedding.py
# - rotary.py
# - mlp.py
# - xlm_padding.py
# - mha.py
# - block.py
# . Make sure to double-check they do not contain any added malicious code. To avoid downloading new versions of the code file, you can pin a revision.
# A new version of the following files was downloaded from https://huggingface.co/jinaai/xlm-roberta-flash-implementation:
# - modeling_lora.py
# - modeling_xlm_roberta.py
# . Make sure to double-check they do not contain any added malicious code. To avoid downloading new versions of the code file, you can pin a revision.
# 2025-06-27 16:26:25.901044: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1751041586.072571      19 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1751041586.124529      19 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# model.safetensors:   0%|          | 0.00/1.14G [00:00<?, ?B/s]
# XLMRobertaLoRA(
#   (roberta): XLMRobertaModel(
#     (embeddings): XLMRobertaEmbeddings(
#       (word_embeddings): ParametrizedEmbedding(
#         250002, 1024, padding_idx=1
#         (parametrizations): ModuleDict(
#           (weight): ParametrizationList(
#             (0): LoRAParametrization()
#           )
#         )
#       )
#       (token_type_embeddings): ParametrizedEmbedding(
#         1, 1024
#         (parametrizations): ModuleDict(
#           (weight): ParametrizationList(
#             (0): LoRAParametrization()
#           )
#         )
#       )
#     )
#     (emb_drop): Dropout(p=0.1, inplace=False)
#     (emb_ln): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#     (encoder): XLMRobertaEncoder(
#       (layers): ModuleList(
#         (0-23): 24 x Block(
#           (mixer): MHA(
#             (rotary_emb): RotaryEmbedding()
#             (Wqkv): ParametrizedLinearResidual(
#               in_features=1024, out_features=3072, bias=True
#               (parametrizations): ModuleDict(
#                 (weight): ParametrizationList(
#                   (0): LoRAParametrization()
#                 )
#               )
#             )
#             (inner_attn): SelfAttention(
#               (drop): Dropout(p=0.1, inplace=False)
#             )
#             (inner_cross_attn): CrossAttention(
#               (drop): Dropout(p=0.1, inplace=False)
#             )
#             (out_proj): ParametrizedLinear(
#               in_features=1024, out_features=1024, bias=True
#               (parametrizations): ModuleDict(
#                 (weight): ParametrizationList(
#                   (0): LoRAParametrization()
#                 )
#               )
#             )
#           )
#           (dropout1): Dropout(p=0.1, inplace=False)
#           (drop_path1): StochasticDepth(p=0.0, mode=row)
#           (norm1): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#           (mlp): Mlp(
#             (fc1): ParametrizedLinear(
#               in_features=1024, out_features=4096, bias=True
#               (parametrizations): ModuleDict(
#                 (weight): ParametrizationList(
#                   (0): LoRAParametrization()
#                 )
#               )
#             )
#             (fc2): ParametrizedLinear(
#               in_features=4096, out_features=1024, bias=True
#               (parametrizations): ModuleDict(
#                 (weight): ParametrizationList(
#                   (0): LoRAParametrization()
#                 )
#               )
#             )
#           )
#           (dropout2): Dropout(p=0.1, inplace=False)
#           (drop_path2): StochasticDepth(p=0.0, mode=row)
#           (norm2): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#         )
#       )
#     )
#     (pooler): XLMRobertaPooler(
#       (dense): ParametrizedLinear(
#         in_features=1024, out_features=1024, bias=True
#         (parametrizations): ModuleDict(
#           (weight): ParametrizationList(
#             (0): LoRAParametrization()
#           )
#         )
#       )
#       (activation): Tanh()
#     )
#   )
# )

# %%
def get_embedding_full(text):
    inputs = tokenizer(text, return_tensors="pt", truncation=True, max_length=256, padding='max_length')
    inputs = {k: v.to(device) for k, v in inputs.items()}
    with torch.no_grad():
        outputs = model_token(**inputs)
        return outputs.last_hidden_state.squeeze(0)

embeddings = []
for text in tqdm(df["text"], desc="Encoding"):
    emb = get_embedding_full(text)
    embeddings.append(emb)
# Out:
# Encoding: 100%|██████████| 5972/5972 [03:49<00:00, 25.97it/s]

# %%
X = pad_sequence(embeddings, batch_first=True)
y_aspect = torch.tensor(df[["aspect_1_enc", "aspect_2_enc"]].values, dtype=torch.long)
y_sentiment = torch.tensor(df[["sentiment_1_enc", "sentiment_2_enc"]].values, dtype=torch.long)

X_cpu = X.cpu()
y_aspect_cpu = y_aspect.cpu()
y_sentiment_cpu = y_sentiment.cpu()

X_temp, X_test, y_a_temp, y_a_test, y_s_temp, y_s_test = train_test_split(
    X_cpu, y_aspect_cpu, y_sentiment_cpu, test_size=0.1, random_state=42
)

X_train, X_val, y_a_train, y_a_val, y_s_train, y_s_val = train_test_split(
    X_temp, y_a_temp, y_s_temp, test_size=0.2222, random_state=42
)

# %%
X_train.shape
# Out:
# torch.Size([4179, 256, 1024])

# %%
class MultiTaskClassifier(nn.Module):
    def __init__(self, input_dim, lstm_hidden_dim, lstm_layers, hidden_dims, 
                 num_aspects, num_sentiments, task_specific_dims=None):
        super().__init__()
        
        # BiLSTM layer
        self.bilstm = nn.LSTM(
            input_size=input_dim,
            hidden_size=lstm_hidden_dim,
            num_layers=lstm_layers,
            batch_first=True,
            bidirectional=True
        )
        
        # Enhanced shared fully connected layers
        layers = []
        prev_dim = lstm_hidden_dim * 2  # *2 because bidirectional
        for hdim in hidden_dims:
            layers.append(nn.Linear(prev_dim, hdim))
            layers.append(nn.ReLU())
            layers.append(nn.Dropout(0.3))
            layers.append(nn.BatchNorm1d(hdim))  # Thêm BatchNorm để ổn định training
            prev_dim = hdim
        self.shared = nn.Sequential(*layers)
        
        # Task-specific dimensions (default nếu không được truyền vào)
        if task_specific_dims is None:
            task_specific_dims = [prev_dim // 2, prev_dim // 4]
        
        # Task-specific layers cho aspect 1
        self.aspect_1_layers = self._create_task_head(prev_dim, task_specific_dims, num_aspects)
        
        # Task-specific layers cho aspect 2  
        self.aspect_2_layers = self._create_task_head(prev_dim, task_specific_dims, num_aspects)
        
        # Task-specific layers cho sentiment 1
        self.sentiment_1_layers = self._create_task_head(prev_dim, task_specific_dims, num_sentiments)
        
        # Task-specific layers cho sentiment 2
        self.sentiment_2_layers = self._create_task_head(prev_dim, task_specific_dims, num_sentiments)
        
    def _create_task_head(self, input_dim, hidden_dims, output_dim):
        """Tạo task-specific head với nhiều lớp linear"""
        layers = []
        prev_dim = input_dim
        
        # Thêm các lớp ẩn
        for hdim in hidden_dims:
            layers.append(nn.Linear(prev_dim, hdim))
            layers.append(nn.ReLU())
            layers.append(nn.Dropout(0.2))  # Dropout thấp hơn cho task-specific layers
            prev_dim = hdim
            
        # Lớp output cuối cùng
        layers.append(nn.Linear(prev_dim, output_dim))
        
        return nn.Sequential(*layers)
        
    def forward(self, x):
        # BiLSTM processing
        lstm_out, _ = self.bilstm(x)
        pooled = torch.mean(lstm_out, dim=1)  # Global average pooling
        
        # Shared feature extraction
        shared_features = self.shared(pooled)
        
        # Pass shared features through task-specific heads
        a1 = self.aspect_1_layers(shared_features)
        a2 = self.aspect_2_layers(shared_features)
        s1 = self.sentiment_1_layers(shared_features)
        s2 = self.sentiment_2_layers(shared_features)
        
        return a1, a2, s1, s2

# %%
class Trainer:
    def __init__(self, model, train_data, val_data, device='cuda',
                 lr=1e-3, batch_size=64, num_epochs=10, step_size=10, gamma=0.5,
                 class_weights=None):
        self.model = model.to(device)
        self.train_data = train_data
        self.val_data = val_data
        self.device = device
        self.lr = lr
        self.batch_size = batch_size
        self.num_epochs = num_epochs

        self.optimizer = torch.optim.Adam(self.model.parameters(), lr=self.lr)
        self.scheduler = torch.optim.lr_scheduler.StepLR(self.optimizer, step_size=step_size, gamma=gamma)

        self.ce_a1 = nn.CrossEntropyLoss(weight=class_weights['a1'].to(device) if class_weights and 'a1' in class_weights else None)
        self.ce_a2 = nn.CrossEntropyLoss(weight=class_weights['a2'].to(device) if class_weights and 'a2' in class_weights else None)
        self.ce_s1 = nn.CrossEntropyLoss(weight=class_weights['s1'].to(device) if class_weights and 's1' in class_weights else None)
        self.ce_s2 = nn.CrossEntropyLoss(weight=class_weights['s2'].to(device) if class_weights and 's2' in class_weights else None)

    def get_batches(self, X, y_aspect, y_sentiment):
        n = len(X)
        for i in range(0, n, self.batch_size):
            yield (
                X[i:i+self.batch_size],
                y_aspect[i:i+self.batch_size],
                y_sentiment[i:i+self.batch_size]
            )

    def train_epoch(self):
        self.model.train()
        total_loss = 0
        total_batches = 0
        X, y_aspect, y_sentiment = self.train_data
        for xb, yb_a, yb_s in self.get_batches(X, y_aspect, y_sentiment):
            xb = xb.to(self.device)
            yb_a = yb_a.to(self.device)
            yb_s = yb_s.to(self.device)

            self.optimizer.zero_grad()
            out_a1, out_a2, out_s1, out_s2 = self.model(xb)

            loss_a1 = self.ce_a1(out_a1, yb_a[:, 0])
            loss_a2 = self.ce_a2(out_a2, yb_a[:, 1])
            loss_s1 = self.ce_s1(out_s1, yb_s[:, 0])
            loss_s2 = self.ce_s2(out_s2, yb_s[:, 1])

            loss = loss_a1 + loss_a2 + loss_s1 + loss_s2
            # loss = loss_a1 * 3 + loss_a2 * 2 + loss_s1 * 2 + loss_s2
            loss.backward()
            self.optimizer.step()

            total_loss += loss.item()
            total_batches += 1

        mean_loss = total_loss / total_batches
        return mean_loss


    def eval_epoch(self):
        self.model.eval()
        total_loss = 0
        total_batches = 0
        y_true_a1, y_pred_a1 = [], []
        y_true_a2, y_pred_a2 = [], []
        y_true_s1, y_pred_s1 = [], []
        y_true_s2, y_pred_s2 = [], []
    
        X, y_aspect, y_sentiment = self.val_data
        with torch.no_grad():
            for xb, yb_a, yb_s in self.get_batches(X, y_aspect, y_sentiment):
                xb = xb.to(self.device)
                yb_a = yb_a.to(self.device)
                yb_s = yb_s.to(self.device)
    
                out_a1, out_a2, out_s1, out_s2 = self.model(xb)

                loss_a1 = self.ce_a1(out_a1, yb_a[:, 0])
                loss_a2 = self.ce_a2(out_a2, yb_a[:, 1])
                loss_s1 = self.ce_s1(out_s1, yb_s[:, 0])
                loss_s2 = self.ce_s2(out_s2, yb_s[:, 1])

                loss = loss_a1 + loss_a2 + loss_s1 + loss_s2
                # loss = loss_a1 * 3 + loss_a2 * 2 + loss_s1 * 2 + loss_s2

                total_loss += loss.item()
                total_batches += 1

                y_true_a1 += yb_a[:, 0].cpu().tolist()
                y_pred_a1 += out_a1.argmax(dim=1).cpu().tolist()
                y_true_a2 += yb_a[:, 1].cpu().tolist()
                y_pred_a2 += out_a2.argmax(dim=1).cpu().tolist()
                y_true_s1 += yb_s[:, 0].cpu().tolist()
                y_pred_s1 += out_s1.argmax(dim=1).cpu().tolist()
                y_true_s2 += yb_s[:, 1].cpu().tolist()
                y_pred_s2 += out_s2.argmax(dim=1).cpu().tolist()

        f1_a1 = f1_score(y_true_a1, y_pred_a1, average="macro")
        f1_a2 = f1_score(y_true_a2, y_pred_a2, average="macro")
        f1_s1 = f1_score(y_true_s1, y_pred_s1, average="macro")
        f1_s2 = f1_score(y_true_s2, y_pred_s2, average="macro")
        avg_f1 = (f1_a1 + f1_a2 + f1_s1 + f1_s2) / 4

        mean_loss = total_loss / total_batches
        print(f"F1 Scores — Aspect1: {f1_a1:.4f}, Aspect2: {f1_a2:.4f}, Sent1: {f1_s1:.4f}, Sent2: {f1_s2:.4f} | Avg: {avg_f1:.4f}")
        return mean_loss


    def train(self):
        for epoch in range(1, self.num_epochs + 1):
            train_loss = self.train_epoch()
            val_loss = self.eval_epoch()
            self.scheduler.step()

            current_lr = self.scheduler.get_last_lr()[0]
            print(f"Epoch {epoch}/{self.num_epochs} | LR: {current_lr:.6f} | Train Loss: {train_loss:.4f} | Val Loss: {val_loss:.4f}")

# %%
def get_batch(X, y_a, y_s, batch_size):
    for i in range(0, len(X), batch_size):
        yield X[i:i+batch_size], y_a[i:i+batch_size], y_s[i:i+batch_size]

# %%
num_aspects = len(aspect_encoder.classes_)
num_sentiments = len(sentiment_encoder.classes_)

# %%
model = MultiTaskClassifier(
    input_dim=1024,
    lstm_hidden_dim=256,
    lstm_layers=2,
    hidden_dims=[1024, 512, 256, 128],  # 4 lớp shared
    num_aspects=num_aspects,
    num_sentiments=num_sentiments,
    task_specific_dims=[128, 64, 32]    # 3 lớp ẩn cho mỗi task head
)
device = "cuda" if torch.cuda.is_available() else "cpu"

trainer = Trainer(
    model=model,
    train_data=(X_train, y_a_train, y_s_train),
    val_data=(X_val, y_a_val, y_s_val),
    device=device,
    lr=4e-3,
    batch_size=32,
    num_epochs=200,
    step_size=10,
    gamma=0.75,
    class_weights={
        'a1': w_aspect,
        'a2': w_aspect,
        's1': w_sentiment,
        's2': w_sentiment
    }
)

# %%
trainer.train()
# Out:
# F1 Scores — Aspect1: 0.2824, Aspect2: 0.1382, Sent1: 0.4377, Sent2: 0.3406 | Avg: 0.2997
# Epoch 1/200 | LR: 0.004000 | Train Loss: 5.5631 | Val Loss: 5.1578
# F1 Scores — Aspect1: 0.3146, Aspect2: 0.1594, Sent1: 0.4475, Sent2: 0.3332 | Avg: 0.3137
# Epoch 2/200 | LR: 0.004000 | Train Loss: 5.0950 | Val Loss: 4.8757
# F1 Scores — Aspect1: 0.2808, Aspect2: 0.2138, Sent1: 0.4708, Sent2: 0.3072 | Avg: 0.3182
# Epoch 3/200 | LR: 0.004000 | Train Loss: 4.9205 | Val Loss: 5.0579
# F1 Scores — Aspect1: 0.4000, Aspect2: 0.1664, Sent1: 0.4424, Sent2: 0.3378 | Avg: 0.3366
# Epoch 4/200 | LR: 0.004000 | Train Loss: 4.9092 | Val Loss: 5.5573
# F1 Scores — Aspect1: 0.4393, Aspect2: 0.2035, Sent1: 0.4527, Sent2: 0.3969 | Avg: 0.3731
# Epoch 5/200 | LR: 0.004000 | Train Loss: 4.7311 | Val Loss: 4.6288
# F1 Scores — Aspect1: 0.4224, Aspect2: 0.1716, Sent1: 0.4635, Sent2: 0.3136 | Avg: 0.3428
# Epoch 6/200 | LR: 0.004000 | Train Loss: 4.7634 | Val Loss: 5.3311
# F1 Scores — Aspect1: 0.5449, Aspect2: 0.1910, Sent1: 0.4582, Sent2: 0.4075 | Avg: 0.4004
# Epoch 7/200 | LR: 0.004000 | Train Loss: 4.6458 | Val Loss: 4.6853
# F1 Scores — Aspect1: 0.5356, Aspect2: 0.1847, Sent1: 0.4667, Sent2: 0.4175 | Avg: 0.4011
# Epoch 8/200 | LR: 0.004000 | Train Loss: 4.6946 | Val Loss: 4.4513
# F1 Scores — Aspect1: 0.2709, Aspect2: 0.1448, Sent1: 0.3715, Sent2: 0.2660 | Avg: 0.2633
# Epoch 9/200 | LR: 0.004000 | Train Loss: 4.5800 | Val Loss: 9.0293
# F1 Scores — Aspect1: 0.4311, Aspect2: 0.1985, Sent1: 0.4843, Sent2: 0.4279 | Avg: 0.3854
# Epoch 10/200 | LR: 0.003000 | Train Loss: 4.5041 | Val Loss: 4.5233
# F1 Scores — Aspect1: 0.5546, Aspect2: 0.2325, Sent1: 0.4827, Sent2: 0.4796 | Avg: 0.4374
# Epoch 11/200 | LR: 0.003000 | Train Loss: 4.3963 | Val Loss: 4.2915
# F1 Scores — Aspect1: 0.5391, Aspect2: 0.2164, Sent1: 0.4677, Sent2: 0.4618 | Avg: 0.4213
# Epoch 12/200 | LR: 0.003000 | Train Loss: 4.3129 | Val Loss: 4.3782
# F1 Scores — Aspect1: 0.4474, Aspect2: 0.2358, Sent1: 0.5524, Sent2: 0.4580 | Avg: 0.4234
# Epoch 13/200 | LR: 0.003000 | Train Loss: 4.2897 | Val Loss: 4.2973
# F1 Scores — Aspect1: 0.4380, Aspect2: 0.2194, Sent1: 0.5530, Sent2: 0.4613 | Avg: 0.4179
# Epoch 14/200 | LR: 0.003000 | Train Loss: 4.3904 | Val Loss: 4.5034
# F1 Scores — Aspect1: 0.4734, Aspect2: 0.2466, Sent1: 0.5014, Sent2: 0.4824 | Avg: 0.4260
# Epoch 15/200 | LR: 0.003000 | Train Loss: 4.3781 | Val Loss: 4.3252
# F1 Scores — Aspect1: 0.4821, Aspect2: 0.1825, Sent1: 0.4701, Sent2: 0.4692 | Avg: 0.4010
# Epoch 16/200 | LR: 0.003000 | Train Loss: 4.2186 | Val Loss: 4.9064
# F1 Scores — Aspect1: 0.6134, Aspect2: 0.2169, Sent1: 0.5139, Sent2: 0.4881 | Avg: 0.4581
# Epoch 17/200 | LR: 0.003000 | Train Loss: 4.1870 | Val Loss: 4.1018
# F1 Scores — Aspect1: 0.5996, Aspect2: 0.2422, Sent1: 0.5058, Sent2: 0.4759 | Avg: 0.4559
# Epoch 18/200 | LR: 0.003000 | Train Loss: 4.1022 | Val Loss: 4.9322
# F1 Scores — Aspect1: 0.5480, Aspect2: 0.2574, Sent1: 0.4861, Sent2: 0.4567 | Avg: 0.4371
# Epoch 19/200 | LR: 0.003000 | Train Loss: 4.0785 | Val Loss: 4.2075
# F1 Scores — Aspect1: 0.6069, Aspect2: 0.2665, Sent1: 0.5547, Sent2: 0.5093 | Avg: 0.4843
# Epoch 20/200 | LR: 0.002250 | Train Loss: 4.0874 | Val Loss: 4.0612
# F1 Scores — Aspect1: 0.6399, Aspect2: 0.3115, Sent1: 0.5666, Sent2: 0.5128 | Avg: 0.5077
# Epoch 21/200 | LR: 0.002250 | Train Loss: 3.9869 | Val Loss: 3.9302
# F1 Scores — Aspect1: 0.6609, Aspect2: 0.3300, Sent1: 0.5692, Sent2: 0.4810 | Avg: 0.5103
# Epoch 22/200 | LR: 0.002250 | Train Loss: 3.9171 | Val Loss: 3.9580
# F1 Scores — Aspect1: 0.6405, Aspect2: 0.3358, Sent1: 0.5965, Sent2: 0.4867 | Avg: 0.5149
# Epoch 23/200 | LR: 0.002250 | Train Loss: 3.9057 | Val Loss: 3.9288
# F1 Scores — Aspect1: 0.6649, Aspect2: 0.2883, Sent1: 0.5595, Sent2: 0.4871 | Avg: 0.4999
# Epoch 24/200 | LR: 0.002250 | Train Loss: 3.8947 | Val Loss: 3.9557
# F1 Scores — Aspect1: 0.4172, Aspect2: 0.1864, Sent1: 0.5140, Sent2: 0.3590 | Avg: 0.3691
# Epoch 25/200 | LR: 0.002250 | Train Loss: 3.8886 | Val Loss: 5.6166
# F1 Scores — Aspect1: 0.6303, Aspect2: 0.2452, Sent1: 0.5915, Sent2: 0.4989 | Avg: 0.4915
# Epoch 26/200 | LR: 0.002250 | Train Loss: 4.1031 | Val Loss: 3.9482
# F1 Scores — Aspect1: 0.6578, Aspect2: 0.2338, Sent1: 0.5804, Sent2: 0.4706 | Avg: 0.4856
# Epoch 27/200 | LR: 0.002250 | Train Loss: 3.9749 | Val Loss: 4.5231
# F1 Scores — Aspect1: 0.6066, Aspect2: 0.3699, Sent1: 0.5757, Sent2: 0.4846 | Avg: 0.5092
# Epoch 28/200 | LR: 0.002250 | Train Loss: 3.9287 | Val Loss: 4.0295
# F1 Scores — Aspect1: 0.6786, Aspect2: 0.3460, Sent1: 0.5756, Sent2: 0.4757 | Avg: 0.5190
# Epoch 29/200 | LR: 0.002250 | Train Loss: 3.9005 | Val Loss: 3.9743
# F1 Scores — Aspect1: 0.4575, Aspect2: 0.2349, Sent1: 0.5631, Sent2: 0.4338 | Avg: 0.4223
# Epoch 30/200 | LR: 0.001688 | Train Loss: 3.8656 | Val Loss: 770.9868
# F1 Scores — Aspect1: 0.6327, Aspect2: 0.3129, Sent1: 0.5744, Sent2: 0.5135 | Avg: 0.5084
# Epoch 31/200 | LR: 0.001688 | Train Loss: 3.8150 | Val Loss: 3.9410
# F1 Scores — Aspect1: 0.6428, Aspect2: 0.2907, Sent1: 0.5543, Sent2: 0.4923 | Avg: 0.4950
# Epoch 32/200 | LR: 0.001688 | Train Loss: 3.9408 | Val Loss: 3.9868
# F1 Scores — Aspect1: 0.6270, Aspect2: 0.3338, Sent1: 0.6054, Sent2: 0.5009 | Avg: 0.5168
# Epoch 33/200 | LR: 0.001688 | Train Loss: 3.8823 | Val Loss: 3.9073
# F1 Scores — Aspect1: 0.6574, Aspect2: 0.3430, Sent1: 0.5892, Sent2: 0.5030 | Avg: 0.5231
# Epoch 34/200 | LR: 0.001688 | Train Loss: 3.9159 | Val Loss: 3.9349
# F1 Scores — Aspect1: 0.0641, Aspect2: 0.0149, Sent1: 0.2739, Sent2: 0.1850 | Avg: 0.1345
# Epoch 35/200 | LR: 0.001688 | Train Loss: 3.8292 | Val Loss: 6069.8352
# F1 Scores — Aspect1: 0.6438, Aspect2: 0.3241, Sent1: 0.5883, Sent2: 0.4956 | Avg: 0.5129
# Epoch 36/200 | LR: 0.001688 | Train Loss: 3.8455 | Val Loss: 4.5210
# F1 Scores — Aspect1: 0.6619, Aspect2: 0.4001, Sent1: 0.5854, Sent2: 0.4855 | Avg: 0.5333
# Epoch 37/200 | LR: 0.001688 | Train Loss: 3.7840 | Val Loss: 3.9124
# F1 Scores — Aspect1: 0.6457, Aspect2: 0.3700, Sent1: 0.6024, Sent2: 0.4853 | Avg: 0.5259
# Epoch 38/200 | LR: 0.001688 | Train Loss: 3.7148 | Val Loss: 3.8759
# F1 Scores — Aspect1: 0.6463, Aspect2: 0.3316, Sent1: 0.5471, Sent2: 0.4690 | Avg: 0.4985
# Epoch 39/200 | LR: 0.001688 | Train Loss: 3.7300 | Val Loss: 8.3126
# F1 Scores — Aspect1: 0.6682, Aspect2: 0.4103, Sent1: 0.5584, Sent2: 0.4831 | Avg: 0.5300
# Epoch 40/200 | LR: 0.001266 | Train Loss: 3.7224 | Val Loss: 3.9098
# F1 Scores — Aspect1: 0.6646, Aspect2: 0.3904, Sent1: 0.5991, Sent2: 0.4947 | Avg: 0.5372
# Epoch 41/200 | LR: 0.001266 | Train Loss: 3.6470 | Val Loss: 3.8224
# F1 Scores — Aspect1: 0.6653, Aspect2: 0.3930, Sent1: 0.5886, Sent2: 0.4873 | Avg: 0.5335
# Epoch 42/200 | LR: 0.001266 | Train Loss: 3.6324 | Val Loss: 3.7924
# F1 Scores — Aspect1: 0.6752, Aspect2: 0.3945, Sent1: 0.5999, Sent2: 0.5040 | Avg: 0.5434
# Epoch 43/200 | LR: 0.001266 | Train Loss: 3.6071 | Val Loss: 3.8275
# F1 Scores — Aspect1: 0.7009, Aspect2: 0.3675, Sent1: 0.5791, Sent2: 0.5152 | Avg: 0.5406
# Epoch 44/200 | LR: 0.001266 | Train Loss: 3.5811 | Val Loss: 3.8372
# F1 Scores — Aspect1: 0.6785, Aspect2: 0.3988, Sent1: 0.5760, Sent2: 0.5019 | Avg: 0.5388
# Epoch 45/200 | LR: 0.001266 | Train Loss: 3.5209 | Val Loss: 3.8967
# F1 Scores — Aspect1: 0.6956, Aspect2: 0.4037, Sent1: 0.6024, Sent2: 0.5058 | Avg: 0.5519
# Epoch 46/200 | LR: 0.001266 | Train Loss: 3.5346 | Val Loss: 3.7953
# F1 Scores — Aspect1: 0.6817, Aspect2: 0.3548, Sent1: 0.6094, Sent2: 0.4852 | Avg: 0.5328
# Epoch 47/200 | LR: 0.001266 | Train Loss: 3.5321 | Val Loss: 3.8442
# F1 Scores — Aspect1: 0.6575, Aspect2: 0.4372, Sent1: 0.6069, Sent2: 0.5143 | Avg: 0.5540
# Epoch 48/200 | LR: 0.001266 | Train Loss: 3.4807 | Val Loss: 3.8216
# F1 Scores — Aspect1: 0.6836, Aspect2: 0.3827, Sent1: 0.5985, Sent2: 0.5042 | Avg: 0.5423
# Epoch 49/200 | LR: 0.001266 | Train Loss: 3.4714 | Val Loss: 3.8515
# F1 Scores — Aspect1: 0.7095, Aspect2: 0.4291, Sent1: 0.5920, Sent2: 0.4768 | Avg: 0.5519
# Epoch 50/200 | LR: 0.000949 | Train Loss: 3.4398 | Val Loss: 3.9333
# F1 Scores — Aspect1: 0.6936, Aspect2: 0.4167, Sent1: 0.5887, Sent2: 0.4967 | Avg: 0.5489
# Epoch 51/200 | LR: 0.000949 | Train Loss: 3.4247 | Val Loss: 3.8832
# F1 Scores — Aspect1: 0.7027, Aspect2: 0.3903, Sent1: 0.5959, Sent2: 0.5018 | Avg: 0.5477
# Epoch 52/200 | LR: 0.000949 | Train Loss: 3.3834 | Val Loss: 3.8840
# F1 Scores — Aspect1: 0.7007, Aspect2: 0.4693, Sent1: 0.6066, Sent2: 0.5182 | Avg: 0.5737
# Epoch 53/200 | LR: 0.000949 | Train Loss: 3.3884 | Val Loss: 3.8312
# F1 Scores — Aspect1: 0.7117, Aspect2: 0.4810, Sent1: 0.6103, Sent2: 0.5289 | Avg: 0.5830
# Epoch 54/200 | LR: 0.000949 | Train Loss: 3.3430 | Val Loss: 3.8224
# F1 Scores — Aspect1: 0.7060, Aspect2: 0.4658, Sent1: 0.6116, Sent2: 0.5193 | Avg: 0.5757
# Epoch 55/200 | LR: 0.000949 | Train Loss: 3.3709 | Val Loss: 3.8331
# F1 Scores — Aspect1: 0.6952, Aspect2: 0.4496, Sent1: 0.6112, Sent2: 0.5181 | Avg: 0.5685
# Epoch 56/200 | LR: 0.000949 | Train Loss: 3.3378 | Val Loss: 3.8444
# F1 Scores — Aspect1: 0.6988, Aspect2: 0.4458, Sent1: 0.6095, Sent2: 0.5030 | Avg: 0.5643
# Epoch 57/200 | LR: 0.000949 | Train Loss: 3.3287 | Val Loss: 3.8536
# F1 Scores — Aspect1: 0.6872, Aspect2: 0.4805, Sent1: 0.6047, Sent2: 0.5191 | Avg: 0.5729
# Epoch 58/200 | LR: 0.000949 | Train Loss: 3.3433 | Val Loss: 3.8905
# F1 Scores — Aspect1: 0.6687, Aspect2: 0.4608, Sent1: 0.5878, Sent2: 0.5355 | Avg: 0.5632
# Epoch 59/200 | LR: 0.000949 | Train Loss: 3.2927 | Val Loss: 3.9425
# F1 Scores — Aspect1: 0.6783, Aspect2: 0.4689, Sent1: 0.6025, Sent2: 0.5405 | Avg: 0.5725
# Epoch 60/200 | LR: 0.000712 | Train Loss: 3.2934 | Val Loss: 3.8200
# F1 Scores — Aspect1: 0.6764, Aspect2: 0.4714, Sent1: 0.5945, Sent2: 0.5323 | Avg: 0.5687
# Epoch 61/200 | LR: 0.000712 | Train Loss: 3.2316 | Val Loss: 3.9201
# F1 Scores — Aspect1: 0.7092, Aspect2: 0.4940, Sent1: 0.6104, Sent2: 0.5198 | Avg: 0.5834
# Epoch 62/200 | LR: 0.000712 | Train Loss: 3.2504 | Val Loss: 4.9521
# F1 Scores — Aspect1: 0.6937, Aspect2: 0.5036, Sent1: 0.5943, Sent2: 0.5362 | Avg: 0.5819
# Epoch 63/200 | LR: 0.000712 | Train Loss: 3.2214 | Val Loss: 3.8742
# F1 Scores — Aspect1: 0.7050, Aspect2: 0.4923, Sent1: 0.6197, Sent2: 0.5421 | Avg: 0.5898
# Epoch 64/200 | LR: 0.000712 | Train Loss: 3.2087 | Val Loss: 3.8245
# F1 Scores — Aspect1: 0.6866, Aspect2: 0.4982, Sent1: 0.6054, Sent2: 0.5352 | Avg: 0.5814
# Epoch 65/200 | LR: 0.000712 | Train Loss: 3.1827 | Val Loss: 3.8382
# F1 Scores — Aspect1: 0.6984, Aspect2: 0.4766, Sent1: 0.6239, Sent2: 0.5377 | Avg: 0.5841
# Epoch 66/200 | LR: 0.000712 | Train Loss: 3.1109 | Val Loss: 3.9398
# F1 Scores — Aspect1: 0.6945, Aspect2: 0.4921, Sent1: 0.6180, Sent2: 0.5340 | Avg: 0.5847
# Epoch 67/200 | LR: 0.000712 | Train Loss: 3.1217 | Val Loss: 3.9235
# F1 Scores — Aspect1: 0.7048, Aspect2: 0.5089, Sent1: 0.6244, Sent2: 0.5445 | Avg: 0.5956
# Epoch 68/200 | LR: 0.000712 | Train Loss: 3.1187 | Val Loss: 3.9223
# F1 Scores — Aspect1: 0.6909, Aspect2: 0.4973, Sent1: 0.6137, Sent2: 0.5459 | Avg: 0.5870
# Epoch 69/200 | LR: 0.000712 | Train Loss: 3.0845 | Val Loss: 3.8384
# F1 Scores — Aspect1: 0.7036, Aspect2: 0.4948, Sent1: 0.6282, Sent2: 0.5265 | Avg: 0.5883
# Epoch 70/200 | LR: 0.000534 | Train Loss: 3.0811 | Val Loss: 3.9903
# F1 Scores — Aspect1: 0.6981, Aspect2: 0.4967, Sent1: 0.6206, Sent2: 0.5311 | Avg: 0.5866
# Epoch 71/200 | LR: 0.000534 | Train Loss: 3.0679 | Val Loss: 3.9936
# F1 Scores — Aspect1: 0.6963, Aspect2: 0.5009, Sent1: 0.6149, Sent2: 0.5271 | Avg: 0.5848
# Epoch 72/200 | LR: 0.000534 | Train Loss: 3.0352 | Val Loss: 3.9728
# F1 Scores — Aspect1: 0.6878, Aspect2: 0.5059, Sent1: 0.6340, Sent2: 0.5315 | Avg: 0.5898
# Epoch 73/200 | LR: 0.000534 | Train Loss: 3.0622 | Val Loss: 3.9155
# F1 Scores — Aspect1: 0.7050, Aspect2: 0.4959, Sent1: 0.6216, Sent2: 0.5256 | Avg: 0.5870
# Epoch 74/200 | LR: 0.000534 | Train Loss: 3.0412 | Val Loss: 3.9826
# F1 Scores — Aspect1: 0.6967, Aspect2: 0.5168, Sent1: 0.6108, Sent2: 0.5208 | Avg: 0.5863
# Epoch 75/200 | LR: 0.000534 | Train Loss: 3.0045 | Val Loss: 3.9921
# F1 Scores — Aspect1: 0.6980, Aspect2: 0.5119, Sent1: 0.6140, Sent2: 0.5313 | Avg: 0.5888
# Epoch 76/200 | LR: 0.000534 | Train Loss: 3.0145 | Val Loss: 3.9090
# F1 Scores — Aspect1: 0.6982, Aspect2: 0.4913, Sent1: 0.6191, Sent2: 0.5283 | Avg: 0.5842
# Epoch 77/200 | LR: 0.000534 | Train Loss: 2.9767 | Val Loss: 3.9156
# F1 Scores — Aspect1: 0.6884, Aspect2: 0.5074, Sent1: 0.6304, Sent2: 0.5293 | Avg: 0.5889
# Epoch 78/200 | LR: 0.000534 | Train Loss: 2.9744 | Val Loss: 3.9415
# F1 Scores — Aspect1: 0.6989, Aspect2: 0.4961, Sent1: 0.6270, Sent2: 0.5254 | Avg: 0.5868
# Epoch 79/200 | LR: 0.000534 | Train Loss: 2.9983 | Val Loss: 3.9751
# F1 Scores — Aspect1: 0.7014, Aspect2: 0.4801, Sent1: 0.6086, Sent2: 0.5263 | Avg: 0.5791
# Epoch 80/200 | LR: 0.000400 | Train Loss: 2.9265 | Val Loss: 4.1008
# F1 Scores — Aspect1: 0.6973, Aspect2: 0.5004, Sent1: 0.6359, Sent2: 0.5244 | Avg: 0.5895
# Epoch 81/200 | LR: 0.000400 | Train Loss: 2.9309 | Val Loss: 3.9791
# F1 Scores — Aspect1: 0.6966, Aspect2: 0.5080, Sent1: 0.6336, Sent2: 0.5376 | Avg: 0.5939
# Epoch 82/200 | LR: 0.000400 | Train Loss: 2.9022 | Val Loss: 3.9796
# F1 Scores — Aspect1: 0.7001, Aspect2: 0.5053, Sent1: 0.6272, Sent2: 0.5268 | Avg: 0.5899
# Epoch 83/200 | LR: 0.000400 | Train Loss: 2.8830 | Val Loss: 3.9849
# F1 Scores — Aspect1: 0.6805, Aspect2: 0.4994, Sent1: 0.6269, Sent2: 0.5213 | Avg: 0.5820
# Epoch 84/200 | LR: 0.000400 | Train Loss: 2.8807 | Val Loss: 4.0219
# F1 Scores — Aspect1: 0.7100, Aspect2: 0.4914, Sent1: 0.6398, Sent2: 0.5260 | Avg: 0.5918
# Epoch 85/200 | LR: 0.000400 | Train Loss: 2.8932 | Val Loss: 4.0313
# F1 Scores — Aspect1: 0.7124, Aspect2: 0.5238, Sent1: 0.6354, Sent2: 0.5250 | Avg: 0.5992
# Epoch 86/200 | LR: 0.000400 | Train Loss: 2.8746 | Val Loss: 4.0104
# F1 Scores — Aspect1: 0.6987, Aspect2: 0.5092, Sent1: 0.6350, Sent2: 0.5340 | Avg: 0.5942
# Epoch 87/200 | LR: 0.000400 | Train Loss: 2.8466 | Val Loss: 4.0639
# F1 Scores — Aspect1: 0.6961, Aspect2: 0.5064, Sent1: 0.6442, Sent2: 0.5251 | Avg: 0.5930
# Epoch 88/200 | LR: 0.000400 | Train Loss: 2.8890 | Val Loss: 3.9867
# F1 Scores — Aspect1: 0.6975, Aspect2: 0.5049, Sent1: 0.6304, Sent2: 0.5233 | Avg: 0.5890
# Epoch 89/200 | LR: 0.000400 | Train Loss: 2.8424 | Val Loss: 4.0160
# F1 Scores — Aspect1: 0.7060, Aspect2: 0.5124, Sent1: 0.6187, Sent2: 0.5090 | Avg: 0.5865
# Epoch 90/200 | LR: 0.000300 | Train Loss: 2.8436 | Val Loss: 4.0412
# F1 Scores — Aspect1: 0.6949, Aspect2: 0.5327, Sent1: 0.6277, Sent2: 0.5179 | Avg: 0.5933
# Epoch 91/200 | LR: 0.000300 | Train Loss: 2.8103 | Val Loss: 4.0316
# F1 Scores — Aspect1: 0.6871, Aspect2: 0.5341, Sent1: 0.6388, Sent2: 0.5244 | Avg: 0.5961
# Epoch 92/200 | LR: 0.000300 | Train Loss: 2.8099 | Val Loss: 4.0520
# F1 Scores — Aspect1: 0.7061, Aspect2: 0.5195, Sent1: 0.6302, Sent2: 0.5188 | Avg: 0.5937
# Epoch 93/200 | LR: 0.000300 | Train Loss: 2.8352 | Val Loss: 4.0830
# F1 Scores — Aspect1: 0.6910, Aspect2: 0.5190, Sent1: 0.6274, Sent2: 0.5114 | Avg: 0.5872
# Epoch 94/200 | LR: 0.000300 | Train Loss: 2.7760 | Val Loss: 4.1188
# F1 Scores — Aspect1: 0.6955, Aspect2: 0.5213, Sent1: 0.6225, Sent2: 0.5147 | Avg: 0.5885
# Epoch 95/200 | LR: 0.000300 | Train Loss: 2.7527 | Val Loss: 4.0139
# F1 Scores — Aspect1: 0.7109, Aspect2: 0.5162, Sent1: 0.6250, Sent2: 0.5150 | Avg: 0.5918
# Epoch 96/200 | LR: 0.000300 | Train Loss: 2.7875 | Val Loss: 4.1310
# F1 Scores — Aspect1: 0.6976, Aspect2: 0.5063, Sent1: 0.6289, Sent2: 0.5134 | Avg: 0.5866
# Epoch 97/200 | LR: 0.000300 | Train Loss: 2.7901 | Val Loss: 4.0945
# F1 Scores — Aspect1: 0.6999, Aspect2: 0.5309, Sent1: 0.6409, Sent2: 0.5278 | Avg: 0.5999
# Epoch 98/200 | LR: 0.000300 | Train Loss: 2.7337 | Val Loss: 4.1041
# F1 Scores — Aspect1: 0.7043, Aspect2: 0.5227, Sent1: 0.6323, Sent2: 0.5212 | Avg: 0.5951
# Epoch 99/200 | LR: 0.000300 | Train Loss: 2.7725 | Val Loss: 4.0391
# F1 Scores — Aspect1: 0.7042, Aspect2: 0.5124, Sent1: 0.6328, Sent2: 0.5139 | Avg: 0.5908
# Epoch 100/200 | LR: 0.000225 | Train Loss: 2.7349 | Val Loss: 4.1171
# F1 Scores — Aspect1: 0.7071, Aspect2: 0.5241, Sent1: 0.6269, Sent2: 0.5216 | Avg: 0.5949
# Epoch 101/200 | LR: 0.000225 | Train Loss: 2.7162 | Val Loss: 4.5267
# F1 Scores — Aspect1: 0.7107, Aspect2: 0.5230, Sent1: 0.6251, Sent2: 0.5205 | Avg: 0.5948
# Epoch 102/200 | LR: 0.000225 | Train Loss: 2.7214 | Val Loss: 4.0933
# F1 Scores — Aspect1: 0.6977, Aspect2: 0.5183, Sent1: 0.6305, Sent2: 0.5233 | Avg: 0.5925
# Epoch 103/200 | LR: 0.000225 | Train Loss: 2.6910 | Val Loss: 4.1297
# F1 Scores — Aspect1: 0.7133, Aspect2: 0.5137, Sent1: 0.6323, Sent2: 0.5205 | Avg: 0.5949
# Epoch 104/200 | LR: 0.000225 | Train Loss: 2.7267 | Val Loss: 4.1417
# F1 Scores — Aspect1: 0.6987, Aspect2: 0.5196, Sent1: 0.6279, Sent2: 0.5247 | Avg: 0.5927
# Epoch 105/200 | LR: 0.000225 | Train Loss: 2.6763 | Val Loss: 4.1503
# F1 Scores — Aspect1: 0.7035, Aspect2: 0.5187, Sent1: 0.6282, Sent2: 0.5241 | Avg: 0.5936
# Epoch 106/200 | LR: 0.000225 | Train Loss: 2.7015 | Val Loss: 4.1591
# F1 Scores — Aspect1: 0.6944, Aspect2: 0.5152, Sent1: 0.6335, Sent2: 0.5172 | Avg: 0.5901
# Epoch 107/200 | LR: 0.000225 | Train Loss: 2.6894 | Val Loss: 4.1820
# F1 Scores — Aspect1: 0.6932, Aspect2: 0.5112, Sent1: 0.6321, Sent2: 0.5233 | Avg: 0.5899
# Epoch 108/200 | LR: 0.000225 | Train Loss: 2.6753 | Val Loss: 4.1712
# F1 Scores — Aspect1: 0.6874, Aspect2: 0.5103, Sent1: 0.6342, Sent2: 0.5228 | Avg: 0.5887
# Epoch 109/200 | LR: 0.000225 | Train Loss: 2.6638 | Val Loss: 4.0999
# F1 Scores — Aspect1: 0.6967, Aspect2: 0.5205, Sent1: 0.6344, Sent2: 0.5229 | Avg: 0.5936
# Epoch 110/200 | LR: 0.000169 | Train Loss: 2.6755 | Val Loss: 4.2108
# F1 Scores — Aspect1: 0.7019, Aspect2: 0.5275, Sent1: 0.6298, Sent2: 0.5260 | Avg: 0.5963
# Epoch 111/200 | LR: 0.000169 | Train Loss: 2.6643 | Val Loss: 4.2567
# F1 Scores — Aspect1: 0.6989, Aspect2: 0.5300, Sent1: 0.6249, Sent2: 0.5247 | Avg: 0.5946
# Epoch 112/200 | LR: 0.000169 | Train Loss: 2.6356 | Val Loss: 4.1935
# F1 Scores — Aspect1: 0.6989, Aspect2: 0.5201, Sent1: 0.6334, Sent2: 0.5212 | Avg: 0.5934
# Epoch 113/200 | LR: 0.000169 | Train Loss: 2.6345 | Val Loss: 4.1977
# F1 Scores — Aspect1: 0.7074, Aspect2: 0.5276, Sent1: 0.6254, Sent2: 0.5198 | Avg: 0.5951
# Epoch 114/200 | LR: 0.000169 | Train Loss: 2.6004 | Val Loss: 4.1877
# F1 Scores — Aspect1: 0.7061, Aspect2: 0.5218, Sent1: 0.6343, Sent2: 0.5255 | Avg: 0.5969
# Epoch 115/200 | LR: 0.000169 | Train Loss: 2.6122 | Val Loss: 4.2218
# F1 Scores — Aspect1: 0.7013, Aspect2: 0.5172, Sent1: 0.6347, Sent2: 0.5281 | Avg: 0.5953
# Epoch 116/200 | LR: 0.000169 | Train Loss: 2.6223 | Val Loss: 4.1598
# F1 Scores — Aspect1: 0.7130, Aspect2: 0.5296, Sent1: 0.6275, Sent2: 0.5247 | Avg: 0.5987
# Epoch 117/200 | LR: 0.000169 | Train Loss: 2.6100 | Val Loss: 4.2251
# F1 Scores — Aspect1: 0.7040, Aspect2: 0.5311, Sent1: 0.6380, Sent2: 0.5319 | Avg: 0.6013
# Epoch 118/200 | LR: 0.000169 | Train Loss: 2.5990 | Val Loss: 4.2122
# F1 Scores — Aspect1: 0.7114, Aspect2: 0.5271, Sent1: 0.6404, Sent2: 0.5311 | Avg: 0.6025
# Epoch 119/200 | LR: 0.000169 | Train Loss: 2.5812 | Val Loss: 4.2331
# F1 Scores — Aspect1: 0.7057, Aspect2: 0.5276, Sent1: 0.6442, Sent2: 0.5330 | Avg: 0.6026
# Epoch 120/200 | LR: 0.000127 | Train Loss: 2.5916 | Val Loss: 4.1828
# F1 Scores — Aspect1: 0.7002, Aspect2: 0.5200, Sent1: 0.6364, Sent2: 0.5281 | Avg: 0.5962
# Epoch 121/200 | LR: 0.000127 | Train Loss: 2.6137 | Val Loss: 4.2790
# F1 Scores — Aspect1: 0.7102, Aspect2: 0.5276, Sent1: 0.6419, Sent2: 0.5260 | Avg: 0.6014
# Epoch 122/200 | LR: 0.000127 | Train Loss: 2.6061 | Val Loss: 4.2234
# F1 Scores — Aspect1: 0.7039, Aspect2: 0.5281, Sent1: 0.6367, Sent2: 0.5183 | Avg: 0.5967
# Epoch 123/200 | LR: 0.000127 | Train Loss: 2.5497 | Val Loss: 4.2717
# F1 Scores — Aspect1: 0.7015, Aspect2: 0.5356, Sent1: 0.6422, Sent2: 0.5259 | Avg: 0.6013
# Epoch 124/200 | LR: 0.000127 | Train Loss: 2.5692 | Val Loss: 4.2815
# F1 Scores — Aspect1: 0.6960, Aspect2: 0.5291, Sent1: 0.6410, Sent2: 0.5312 | Avg: 0.5994
# Epoch 125/200 | LR: 0.000127 | Train Loss: 2.5994 | Val Loss: 4.2287
# F1 Scores — Aspect1: 0.6968, Aspect2: 0.5428, Sent1: 0.6308, Sent2: 0.5333 | Avg: 0.6009
# Epoch 126/200 | LR: 0.000127 | Train Loss: 2.5411 | Val Loss: 4.2653
# F1 Scores — Aspect1: 0.7024, Aspect2: 0.5336, Sent1: 0.6436, Sent2: 0.5277 | Avg: 0.6018
# Epoch 127/200 | LR: 0.000127 | Train Loss: 2.5477 | Val Loss: 4.2780
# F1 Scores — Aspect1: 0.7085, Aspect2: 0.5379, Sent1: 0.6382, Sent2: 0.5269 | Avg: 0.6029
# Epoch 128/200 | LR: 0.000127 | Train Loss: 2.5356 | Val Loss: 4.2433
# F1 Scores — Aspect1: 0.7136, Aspect2: 0.5250, Sent1: 0.6377, Sent2: 0.5241 | Avg: 0.6001
# Epoch 129/200 | LR: 0.000127 | Train Loss: 2.5603 | Val Loss: 4.3002
# F1 Scores — Aspect1: 0.7048, Aspect2: 0.5309, Sent1: 0.6386, Sent2: 0.5181 | Avg: 0.5981
# Epoch 130/200 | LR: 0.000095 | Train Loss: 2.5308 | Val Loss: 4.3549
# F1 Scores — Aspect1: 0.7045, Aspect2: 0.5355, Sent1: 0.6397, Sent2: 0.5246 | Avg: 0.6011
# Epoch 131/200 | LR: 0.000095 | Train Loss: 2.5381 | Val Loss: 9.5862
# F1 Scores — Aspect1: 0.7100, Aspect2: 0.5373, Sent1: 0.6328, Sent2: 0.5246 | Avg: 0.6012
# Epoch 132/200 | LR: 0.000095 | Train Loss: 2.5219 | Val Loss: 10.9605
# F1 Scores — Aspect1: 0.7050, Aspect2: 0.5409, Sent1: 0.6364, Sent2: 0.5168 | Avg: 0.5998
# Epoch 133/200 | LR: 0.000095 | Train Loss: 2.5586 | Val Loss: 4.2889
# F1 Scores — Aspect1: 0.7082, Aspect2: 0.5366, Sent1: 0.6447, Sent2: 0.5191 | Avg: 0.6021
# Epoch 134/200 | LR: 0.000095 | Train Loss: 2.5205 | Val Loss: 9.4899
# F1 Scores — Aspect1: 0.7058, Aspect2: 0.5302, Sent1: 0.6406, Sent2: 0.5109 | Avg: 0.5969
# Epoch 135/200 | LR: 0.000095 | Train Loss: 2.5382 | Val Loss: 17.0822
# F1 Scores — Aspect1: 0.7043, Aspect2: 0.5323, Sent1: 0.6394, Sent2: 0.5178 | Avg: 0.5984
# Epoch 136/200 | LR: 0.000095 | Train Loss: 2.5403 | Val Loss: 11.5299
# F1 Scores — Aspect1: 0.7052, Aspect2: 0.5362, Sent1: 0.6428, Sent2: 0.5225 | Avg: 0.6017
# Epoch 137/200 | LR: 0.000095 | Train Loss: 2.4994 | Val Loss: 10.8175
# F1 Scores — Aspect1: 0.7122, Aspect2: 0.5423, Sent1: 0.6453, Sent2: 0.5195 | Avg: 0.6048
# Epoch 138/200 | LR: 0.000095 | Train Loss: 2.4915 | Val Loss: 4.3430
# F1 Scores — Aspect1: 0.7091, Aspect2: 0.5387, Sent1: 0.6427, Sent2: 0.5271 | Avg: 0.6044
# Epoch 139/200 | LR: 0.000095 | Train Loss: 2.5001 | Val Loss: 4.3757
# F1 Scores — Aspect1: 0.7092, Aspect2: 0.5346, Sent1: 0.6454, Sent2: 0.5246 | Avg: 0.6035
# Epoch 140/200 | LR: 0.000071 | Train Loss: 2.4755 | Val Loss: 6.3690
# F1 Scores — Aspect1: 0.7051, Aspect2: 0.5346, Sent1: 0.6376, Sent2: 0.5201 | Avg: 0.5993
# Epoch 141/200 | LR: 0.000071 | Train Loss: 2.5009 | Val Loss: 4.3386
# F1 Scores — Aspect1: 0.7171, Aspect2: 0.5463, Sent1: 0.6388, Sent2: 0.5293 | Avg: 0.6079
# Epoch 142/200 | LR: 0.000071 | Train Loss: 2.4789 | Val Loss: 4.3821
# F1 Scores — Aspect1: 0.7201, Aspect2: 0.5407, Sent1: 0.6413, Sent2: 0.5197 | Avg: 0.6054
# Epoch 143/200 | LR: 0.000071 | Train Loss: 2.5384 | Val Loss: 4.3687
# F1 Scores — Aspect1: 0.7109, Aspect2: 0.5517, Sent1: 0.6426, Sent2: 0.5248 | Avg: 0.6075
# Epoch 144/200 | LR: 0.000071 | Train Loss: 2.4971 | Val Loss: 4.3541
# F1 Scores — Aspect1: 0.7200, Aspect2: 0.5403, Sent1: 0.6436, Sent2: 0.5203 | Avg: 0.6060
# Epoch 145/200 | LR: 0.000071 | Train Loss: 2.5120 | Val Loss: 6.2955
# F1 Scores — Aspect1: 0.7131, Aspect2: 0.5422, Sent1: 0.6431, Sent2: 0.5276 | Avg: 0.6065
# Epoch 146/200 | LR: 0.000071 | Train Loss: 2.5079 | Val Loss: 4.3646
# F1 Scores — Aspect1: 0.7150, Aspect2: 0.5426, Sent1: 0.6412, Sent2: 0.5263 | Avg: 0.6063
# Epoch 147/200 | LR: 0.000071 | Train Loss: 2.4913 | Val Loss: 4.3670
# F1 Scores — Aspect1: 0.7073, Aspect2: 0.5408, Sent1: 0.6419, Sent2: 0.5303 | Avg: 0.6051
# Epoch 148/200 | LR: 0.000071 | Train Loss: 2.4981 | Val Loss: 6.3187
# F1 Scores — Aspect1: 0.7098, Aspect2: 0.5367, Sent1: 0.6409, Sent2: 0.5218 | Avg: 0.6023
# Epoch 149/200 | LR: 0.000071 | Train Loss: 2.4803 | Val Loss: 5.7020
# F1 Scores — Aspect1: 0.7122, Aspect2: 0.5406, Sent1: 0.6478, Sent2: 0.5226 | Avg: 0.6058
# Epoch 150/200 | LR: 0.000053 | Train Loss: 2.4909 | Val Loss: 4.3931
# F1 Scores — Aspect1: 0.7056, Aspect2: 0.5447, Sent1: 0.6468, Sent2: 0.5264 | Avg: 0.6059
# Epoch 151/200 | LR: 0.000053 | Train Loss: 2.4631 | Val Loss: 4.3824
# F1 Scores — Aspect1: 0.7146, Aspect2: 0.5434, Sent1: 0.6426, Sent2: 0.5314 | Avg: 0.6080
# Epoch 152/200 | LR: 0.000053 | Train Loss: 2.4905 | Val Loss: 4.4114
# F1 Scores — Aspect1: 0.7085, Aspect2: 0.5453, Sent1: 0.6465, Sent2: 0.5291 | Avg: 0.6074
# Epoch 153/200 | LR: 0.000053 | Train Loss: 2.4841 | Val Loss: 4.4271
# F1 Scores — Aspect1: 0.7179, Aspect2: 0.5395, Sent1: 0.6486, Sent2: 0.5287 | Avg: 0.6087
# Epoch 154/200 | LR: 0.000053 | Train Loss: 2.4693 | Val Loss: 4.4197
# F1 Scores — Aspect1: 0.7016, Aspect2: 0.5465, Sent1: 0.6477, Sent2: 0.5299 | Avg: 0.6064
# Epoch 155/200 | LR: 0.000053 | Train Loss: 2.4827 | Val Loss: 4.4289
# F1 Scores — Aspect1: 0.7116, Aspect2: 0.5441, Sent1: 0.6481, Sent2: 0.5334 | Avg: 0.6093
# Epoch 156/200 | LR: 0.000053 | Train Loss: 2.4539 | Val Loss: 4.3973
# F1 Scores — Aspect1: 0.7010, Aspect2: 0.5430, Sent1: 0.6417, Sent2: 0.5283 | Avg: 0.6035
# Epoch 157/200 | LR: 0.000053 | Train Loss: 2.4753 | Val Loss: 4.3999
# F1 Scores — Aspect1: 0.7070, Aspect2: 0.5409, Sent1: 0.6480, Sent2: 0.5347 | Avg: 0.6076
# Epoch 158/200 | LR: 0.000053 | Train Loss: 2.4504 | Val Loss: 4.4047
# F1 Scores — Aspect1: 0.7049, Aspect2: 0.5458, Sent1: 0.6466, Sent2: 0.5312 | Avg: 0.6071
# Epoch 159/200 | LR: 0.000053 | Train Loss: 2.4498 | Val Loss: 4.4719
# F1 Scores — Aspect1: 0.7093, Aspect2: 0.5388, Sent1: 0.6443, Sent2: 0.5306 | Avg: 0.6057
# Epoch 160/200 | LR: 0.000040 | Train Loss: 2.4706 | Val Loss: 4.4600
# F1 Scores — Aspect1: 0.7025, Aspect2: 0.5489, Sent1: 0.6436, Sent2: 0.5244 | Avg: 0.6049
# Epoch 161/200 | LR: 0.000040 | Train Loss: 2.4811 | Val Loss: 4.4441
# F1 Scores — Aspect1: 0.7008, Aspect2: 0.5421, Sent1: 0.6370, Sent2: 0.5256 | Avg: 0.6014
# Epoch 162/200 | LR: 0.000040 | Train Loss: 2.4734 | Val Loss: 4.4336
# F1 Scores — Aspect1: 0.6948, Aspect2: 0.5422, Sent1: 0.6439, Sent2: 0.5240 | Avg: 0.6012
# Epoch 163/200 | LR: 0.000040 | Train Loss: 2.4561 | Val Loss: 4.4456
# F1 Scores — Aspect1: 0.7028, Aspect2: 0.5433, Sent1: 0.6480, Sent2: 0.5287 | Avg: 0.6057
# Epoch 164/200 | LR: 0.000040 | Train Loss: 2.4424 | Val Loss: 4.4589
# F1 Scores — Aspect1: 0.7072, Aspect2: 0.5464, Sent1: 0.6504, Sent2: 0.5338 | Avg: 0.6095
# Epoch 165/200 | LR: 0.000040 | Train Loss: 2.4518 | Val Loss: 4.4523
# F1 Scores — Aspect1: 0.7065, Aspect2: 0.5485, Sent1: 0.6474, Sent2: 0.5312 | Avg: 0.6084
# Epoch 166/200 | LR: 0.000040 | Train Loss: 2.4508 | Val Loss: 4.4204
# F1 Scores — Aspect1: 0.7109, Aspect2: 0.5385, Sent1: 0.6472, Sent2: 0.5340 | Avg: 0.6076
# Epoch 167/200 | LR: 0.000040 | Train Loss: 2.4491 | Val Loss: 4.4585
# F1 Scores — Aspect1: 0.7058, Aspect2: 0.5378, Sent1: 0.6511, Sent2: 0.5338 | Avg: 0.6071
# Epoch 168/200 | LR: 0.000040 | Train Loss: 2.4376 | Val Loss: 4.4520
# F1 Scores — Aspect1: 0.7081, Aspect2: 0.5440, Sent1: 0.6468, Sent2: 0.5323 | Avg: 0.6078
# Epoch 169/200 | LR: 0.000040 | Train Loss: 2.4634 | Val Loss: 4.4471
# F1 Scores — Aspect1: 0.7080, Aspect2: 0.5437, Sent1: 0.6449, Sent2: 0.5358 | Avg: 0.6081
# Epoch 170/200 | LR: 0.000030 | Train Loss: 2.4282 | Val Loss: 5.4742
# F1 Scores — Aspect1: 0.7141, Aspect2: 0.5382, Sent1: 0.6492, Sent2: 0.5327 | Avg: 0.6086
# Epoch 171/200 | LR: 0.000030 | Train Loss: 2.4411 | Val Loss: 4.4728
# F1 Scores — Aspect1: 0.7067, Aspect2: 0.5396, Sent1: 0.6418, Sent2: 0.5323 | Avg: 0.6051
# Epoch 172/200 | LR: 0.000030 | Train Loss: 2.4138 | Val Loss: 4.4954
# F1 Scores — Aspect1: 0.7115, Aspect2: 0.5421, Sent1: 0.6393, Sent2: 0.5347 | Avg: 0.6069
# Epoch 173/200 | LR: 0.000030 | Train Loss: 2.4037 | Val Loss: 4.4564
# F1 Scores — Aspect1: 0.7070, Aspect2: 0.5410, Sent1: 0.6415, Sent2: 0.5354 | Avg: 0.6062
# Epoch 174/200 | LR: 0.000030 | Train Loss: 2.4402 | Val Loss: 4.4778
# F1 Scores — Aspect1: 0.7131, Aspect2: 0.5398, Sent1: 0.6429, Sent2: 0.5345 | Avg: 0.6075
# Epoch 175/200 | LR: 0.000030 | Train Loss: 2.4445 | Val Loss: 6.2658
# F1 Scores — Aspect1: 0.7141, Aspect2: 0.5393, Sent1: 0.6462, Sent2: 0.5326 | Avg: 0.6081
# Epoch 176/200 | LR: 0.000030 | Train Loss: 2.4333 | Val Loss: 4.4965
# F1 Scores — Aspect1: 0.7052, Aspect2: 0.5441, Sent1: 0.6450, Sent2: 0.5293 | Avg: 0.6059
# Epoch 177/200 | LR: 0.000030 | Train Loss: 2.4407 | Val Loss: 4.4742
# F1 Scores — Aspect1: 0.7076, Aspect2: 0.5306, Sent1: 0.6399, Sent2: 0.5254 | Avg: 0.6009
# Epoch 178/200 | LR: 0.000030 | Train Loss: 2.4192 | Val Loss: 4.5191
# F1 Scores — Aspect1: 0.7079, Aspect2: 0.5349, Sent1: 0.6432, Sent2: 0.5307 | Avg: 0.6042
# Epoch 179/200 | LR: 0.000030 | Train Loss: 2.4168 | Val Loss: 4.5048
# F1 Scores — Aspect1: 0.7095, Aspect2: 0.5438, Sent1: 0.6432, Sent2: 0.5322 | Avg: 0.6072
# Epoch 180/200 | LR: 0.000023 | Train Loss: 2.4276 | Val Loss: 4.5342
# F1 Scores — Aspect1: 0.7092, Aspect2: 0.5346, Sent1: 0.6440, Sent2: 0.5339 | Avg: 0.6055
# Epoch 181/200 | LR: 0.000023 | Train Loss: 2.4013 | Val Loss: 4.5256
# F1 Scores — Aspect1: 0.7132, Aspect2: 0.5443, Sent1: 0.6364, Sent2: 0.5357 | Avg: 0.6074
# Epoch 182/200 | LR: 0.000023 | Train Loss: 2.4352 | Val Loss: 4.4777
# F1 Scores — Aspect1: 0.7093, Aspect2: 0.5427, Sent1: 0.6421, Sent2: 0.5350 | Avg: 0.6073
# Epoch 183/200 | LR: 0.000023 | Train Loss: 2.4330 | Val Loss: 4.4608
# F1 Scores — Aspect1: 0.7145, Aspect2: 0.5427, Sent1: 0.6381, Sent2: 0.5352 | Avg: 0.6076
# Epoch 184/200 | LR: 0.000023 | Train Loss: 2.4165 | Val Loss: 4.4766
# F1 Scores — Aspect1: 0.7150, Aspect2: 0.5477, Sent1: 0.6372, Sent2: 0.5315 | Avg: 0.6078
# Epoch 185/200 | LR: 0.000023 | Train Loss: 2.4128 | Val Loss: 4.4753
# F1 Scores — Aspect1: 0.7065, Aspect2: 0.5403, Sent1: 0.6433, Sent2: 0.5307 | Avg: 0.6052
# Epoch 186/200 | LR: 0.000023 | Train Loss: 2.3867 | Val Loss: 4.4884
# F1 Scores — Aspect1: 0.7123, Aspect2: 0.5489, Sent1: 0.6367, Sent2: 0.5325 | Avg: 0.6076
# Epoch 187/200 | LR: 0.000023 | Train Loss: 2.4253 | Val Loss: 4.5129
# F1 Scores — Aspect1: 0.7125, Aspect2: 0.5486, Sent1: 0.6389, Sent2: 0.5342 | Avg: 0.6086
# Epoch 188/200 | LR: 0.000023 | Train Loss: 2.4059 | Val Loss: 4.5294
# F1 Scores — Aspect1: 0.7160, Aspect2: 0.5441, Sent1: 0.6409, Sent2: 0.5315 | Avg: 0.6081
# Epoch 189/200 | LR: 0.000023 | Train Loss: 2.4006 | Val Loss: 4.5134
# F1 Scores — Aspect1: 0.7119, Aspect2: 0.5452, Sent1: 0.6406, Sent2: 0.5314 | Avg: 0.6073
# Epoch 190/200 | LR: 0.000017 | Train Loss: 2.4202 | Val Loss: 4.5468
# F1 Scores — Aspect1: 0.7130, Aspect2: 0.5403, Sent1: 0.6431, Sent2: 0.5347 | Avg: 0.6078
# Epoch 191/200 | LR: 0.000017 | Train Loss: 2.3870 | Val Loss: 4.5267
# F1 Scores — Aspect1: 0.7191, Aspect2: 0.5458, Sent1: 0.6381, Sent2: 0.5341 | Avg: 0.6093
# Epoch 192/200 | LR: 0.000017 | Train Loss: 2.4167 | Val Loss: 4.5170
# F1 Scores — Aspect1: 0.7156, Aspect2: 0.5522, Sent1: 0.6392, Sent2: 0.5375 | Avg: 0.6111
# Epoch 193/200 | LR: 0.000017 | Train Loss: 2.4145 | Val Loss: 4.5069
# F1 Scores — Aspect1: 0.7125, Aspect2: 0.5479, Sent1: 0.6407, Sent2: 0.5370 | Avg: 0.6095
# Epoch 194/200 | LR: 0.000017 | Train Loss: 2.4270 | Val Loss: 4.4903
# F1 Scores — Aspect1: 0.7136, Aspect2: 0.5447, Sent1: 0.6400, Sent2: 0.5323 | Avg: 0.6076
# Epoch 195/200 | LR: 0.000017 | Train Loss: 2.4031 | Val Loss: 4.5199
# F1 Scores — Aspect1: 0.7153, Aspect2: 0.5483, Sent1: 0.6419, Sent2: 0.5354 | Avg: 0.6102
# Epoch 196/200 | LR: 0.000017 | Train Loss: 2.4084 | Val Loss: 4.5163
# F1 Scores — Aspect1: 0.7152, Aspect2: 0.5469, Sent1: 0.6436, Sent2: 0.5310 | Avg: 0.6092
# Epoch 197/200 | LR: 0.000017 | Train Loss: 2.3984 | Val Loss: 4.5249
# F1 Scores — Aspect1: 0.7061, Aspect2: 0.5485, Sent1: 0.6457, Sent2: 0.5364 | Avg: 0.6092
# Epoch 198/200 | LR: 0.000017 | Train Loss: 2.3796 | Val Loss: 4.5207
# F1 Scores — Aspect1: 0.7100, Aspect2: 0.5431, Sent1: 0.6441, Sent2: 0.5356 | Avg: 0.6082
# Epoch 199/200 | LR: 0.000017 | Train Loss: 2.3948 | Val Loss: 4.4993
# F1 Scores — Aspect1: 0.7116, Aspect2: 0.5456, Sent1: 0.6389, Sent2: 0.5330 | Avg: 0.6073
# Epoch 200/200 | LR: 0.000013 | Train Loss: 2.4017 | Val Loss: 6.2770

# %%
from sklearn.metrics import classification_report

def evaluate_on_test(model, test_data, batch_size=8, device='cuda'):
    model.eval()
    X_test, y_a_test, y_s_test = test_data

    y_true_a1, y_pred_a1 = [], []
    y_true_a2, y_pred_a2 = [], []
    y_true_s1, y_pred_s1 = [], []
    y_true_s2, y_pred_s2 = [], []

    with torch.no_grad():
        for i in range(0, len(X_test), batch_size):
            xb = X_test[i:i+batch_size].to(device)
            yb_a = y_a_test[i:i+batch_size].to(device)
            yb_s = y_s_test[i:i+batch_size].to(device)

            out_a1, out_a2, out_s1, out_s2 = model(xb)

            y_true_a1 += yb_a[:, 0].cpu().tolist()
            y_pred_a1 += out_a1.argmax(dim=1).cpu().tolist()
            y_true_a2 += yb_a[:, 1].cpu().tolist()
            y_pred_a2 += out_a2.argmax(dim=1).cpu().tolist()
            y_true_s1 += yb_s[:, 0].cpu().tolist()
            y_pred_s1 += out_s1.argmax(dim=1).cpu().tolist()
            y_true_s2 += yb_s[:, 1].cpu().tolist()
            y_pred_s2 += out_s2.argmax(dim=1).cpu().tolist()

    print("\n--- Test Evaluation ---")
    print("Aspect 1:")
    print(classification_report(y_true_a1, y_pred_a1, digits=4))
    print("Aspect 2:")
    print(classification_report(y_true_a2, y_pred_a2, digits=4))
    print("Sentiment 1:")
    print(classification_report(y_true_s1, y_pred_s1, digits=4))
    print("Sentiment 2:")
    print(classification_report(y_true_s2, y_pred_s2, digits=4))

# %%
evaluate_on_test(model, (X_test, y_a_test, y_s_test), batch_size=8, device=device)
# Out:
# --- Test Evaluation ---
# Aspect 1:
#               precision    recall  f1-score   support
#
#            0     0.8649    0.9143    0.8889        35
#            1     0.7742    0.7059    0.7385        34
#            2     0.5658    0.8600    0.6825        50
#            3     0.6289    0.4692    0.5374       130
#            4     0.6138    0.8162    0.7007       185
#            5     0.7255    0.3458    0.4684       107
#            6     0.9333    0.9825    0.9573        57
#
#     accuracy                         0.6756       598
#    macro avg     0.7295    0.7277    0.7105       598
# weighted avg     0.6873    0.6756    0.6597       598
#
# Aspect 2:
#               precision    recall  f1-score   support
#
#            0     0.6667    0.4444    0.5333         9
#            1     0.3571    0.7692    0.4878        13
#            2     0.6087    0.7568    0.6747        37
#            3     0.5294    0.4821    0.5047        56
#            4     0.7115    0.5873    0.6435        63
#            5     0.6158    0.5896    0.6024       212
#            6     0.3077    0.6667    0.4211         6
#            7     0.6935    0.6832    0.6883       202
#
#     accuracy                         0.6237       598
#    macro avg     0.5613    0.6224    0.5695       598
# weighted avg     0.6356    0.6237    0.6257       598
#
# Sentiment 1:
#               precision    recall  f1-score   support
#
#            0     0.9233    0.7698    0.8396       391
#            1     0.2615    0.6538    0.3736        52
#            3     0.7394    0.6774    0.7071       155
#
#     accuracy                         0.7358       598
#    macro avg     0.6414    0.7004    0.6401       598
# weighted avg     0.8181    0.7358    0.7647       598
#
# Sentiment 2:
#               precision    recall  f1-score   support
#
#            0     0.8681    0.5704    0.6885       277
#            1     0.1240    0.5517    0.2025        29
#            2     0.6931    0.6931    0.6931       202
#            3     0.5412    0.5111    0.5257        90
#
#     accuracy                         0.6020       598
#    macro avg     0.5566    0.5816    0.5274       598
# weighted avg     0.7237    0.6020    0.6420       598

# %%
test_text = """Khoảnh khắc Quang Hùng MasterD "flex" sự học tiếng Hàn cấp tốc để giao lưu với anh Long. 
Fan boy này đi đu idol thành công quá rồi 🤣🤣 
Video: Phạm Thanh Hoa 
Gọi ộp pa thì đội tóc giả nữa a kkk"""

# %%
def predict(text):
    model.eval()
    inputs = tokenizer(text, return_tensors="pt", truncation=True, max_length=256, padding='max_length')
    inputs = {k: v.to(device) for k, v in inputs.items()}

    with torch.no_grad():
        outputs = model_token(**inputs)
        last_hidden = outputs.last_hidden_state  # shape (1, seq_len, 768)

        # Truyền toàn bộ chuỗi token embeddings vào model (model đã có LSTM)
        out_a1, out_a2, out_s1, out_s2 = model(last_hidden)

        pred_a1 = torch.argmax(out_a1, dim=1).cpu().item()
        pred_a2 = torch.argmax(out_a2, dim=1).cpu().item()
        pred_s1 = torch.argmax(out_s1, dim=1).cpu().item()
        pred_s2 = torch.argmax(out_s2, dim=1).cpu().item()

        aspect_1_label = aspect_encoder.inverse_transform([pred_a1])[0]
        aspect_2_label = aspect_encoder.inverse_transform([pred_a2])[0]
        sentiment_1_label = sentiment_encoder.inverse_transform([pred_s1])[0]
        sentiment_2_label = sentiment_encoder.inverse_transform([pred_s2])[0]

        print("=== PREDICTION RESULT ===")
        print(f"Aspect 1:    {aspect_1_label}")
        print(f"Sentiment 1: {sentiment_1_label}")
        print(f"Aspect 2:    {aspect_2_label}")
        print(f"Sentiment 2: {sentiment_2_label}")

# %%
predict(test_text)
# Out:
# === PREDICTION RESULT ===
# Aspect 1:    Art
# Sentiment 1: positive
# Aspect 2:    null
# Sentiment 2: null

# %%
import torch
import joblib
import os

SAVE_DIR = "saved_model"

tokenizer.save_pretrained(SAVE_DIR)
model_token.save_pretrained(SAVE_DIR)

torch.save(model.state_dict(), "classifier.pt")

model_config = {
    "input_dim": 1024,
    "lstm_hidden_dim": 256,
    "lstm_layers": 2,
    "hidden_dims": [1024, 512, 256, 128],
    "num_aspects": num_aspects,
    "num_sentiments": num_sentiments,
    "task_specific_dims": [128, 64, 32]
}

import json
with open("classifier_config.json", "w") as f:
    json.dump(model_config, f)
