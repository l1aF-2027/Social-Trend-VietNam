# %%
import json
import pandas as pd
from tqdm import tqdm
from sklearn.preprocessing import LabelEncoder
from sklearn.metrics import f1_score

from transformers import AutoTokenizer, AutoModel
import torch
import torch.nn.functional as F
from torch.nn.utils.rnn import pad_sequence

from sklearn.model_selection import train_test_split
import torch.nn as nn
from torch.utils.data import DataLoader, TensorDataset
import torch.optim as optim
from torch.optim.lr_scheduler import StepLR

# %%
# !pip install einops
# Out:
# Requirement already satisfied: einops in /usr/local/lib/python3.11/dist-packages (0.8.1)

# %%
with open('/kaggle/input/data-ds200/data_labeled_soft_cleaned.json', 'r', encoding='utf-8') as f:
    raw_data = json.load(f)

def build_text(item):
    parts = [item.get("post_content", "")]
    if 'comment' in item:
        parts += item['comment'].get('parent_comment_texts', [])
        if item['comment'].get('comment_text'):
            parts.append(item['comment']['comment_text'])
    img_descs = [desc['image_description'] for desc in item.get("image_descriptions", [])]
    parts += img_descs
    return "\n".join(parts)

# %%
data = []
for item in raw_data:
    text = build_text(item)
    aspects = [item.get("Aspect_1", "Other"), item.get("Aspect_2") or "null"]
    sentiments = item.get("Sentiment", ["null", "null"])
    data.append({
        "text": text,
        "aspect_1": aspects[0],
        "aspect_2": aspects[1],
        "sentiment_1": sentiments[0],
        "sentiment_2": sentiments[1] if aspects[1] != "null" else "null"
    })

# %%
df = pd.DataFrame(data)
df.head()
# Out:
#                                                 text aspect_1 aspect_2  \
# 0  TÒA ĐÃ TUYÊN PHẠT BỐ RUỘT 6 NĂM TÙ   Bị cáo và...      Law    Other
# 1  TÒA ĐÃ TUYÊN PHẠT BỐ RUỘT 6 NĂM TÙ   Bị cáo và...      Law    Other
# 2  TÒA ĐÃ TUYÊN PHẠT BỐ RUỘT 6 NĂM TÙ   Bị cáo và...      Law   Health
# 3  TÒA ĐÃ TUYÊN PHẠT BỐ RUỘT 6 NĂM TÙ   Bị cáo và...      Law   Health
# 4  TÒA ĐÃ TUYÊN PHẠT BỐ RUỘT 6 NĂM TÙ   Bị cáo và...      Law    Other
#
#   sentiment_1 sentiment_2
# 0    negative    negative
# 1    negative    negative
# 2    negative    negative
# 3    negative    negative
# 4    negative    negative

# %%
all_aspects = pd.concat([df['aspect_1'], df['aspect_2']]).unique()
aspect_encoder = LabelEncoder()
aspect_encoder.fit(all_aspects)

df['aspect_1_enc'] = aspect_encoder.transform(df['aspect_1'])
df['aspect_2_enc'] = aspect_encoder.transform(df['aspect_2'])

# %%
print(aspect_encoder.classes_)
# Out:
# ['Art' 'Fashion' 'Food' 'Health' 'Law' 'Other' 'Sport' 'null']

# %%
# sentiment_map = {"positive": 1.0, "neutral": 0.0, "negative": -1.0}
# df["sentiment_1_score"] = df["sentiment_1"].map(sentiment_map)
# df["sentiment_2_score"] = df["sentiment_2"].map(sentiment_map)

# %%
all_aspects = pd.concat([df['sentiment_1'], df['sentiment_2']]).unique()
sentiment_encoder = LabelEncoder()
sentiment_encoder.fit(all_aspects)

df['sentiment_1_enc'] = sentiment_encoder.transform(df['sentiment_1'])
df['sentiment_2_enc'] = sentiment_encoder.transform(df['sentiment_2'])

# %%
print(sentiment_encoder.classes_)
# Out:
# ['negative' 'neutral' 'null' 'positive']

# %%
from collections import Counter
import numpy as np
import torch

def compute_class_weights(name, combined_labels):
    counts = Counter(combined_labels)
    total = sum(counts.values())
    print(f"\n{name} distribution:")
    for k, v in sorted(counts.items()):
        print(f"  Class {k}: {v} ({v/total:.2%})")

    num_classes = len(counts)
    weights = [total / (num_classes * counts[i]) for i in range(num_classes)]
    print(f"{name} weights: {np.round(weights, 3)}")
    return torch.tensor(weights, dtype=torch.float32)

# %%
# Gộp nhãn aspect
combined_aspect = pd.concat([df["aspect_1_enc"], df["aspect_2_enc"]]).tolist()
w_aspect = compute_class_weights("Aspect", combined_aspect)

# Gộp nhãn sentiment
combined_sentiment = pd.concat([df["sentiment_1_enc"], df["sentiment_2_enc"]]).tolist()
w_sentiment = compute_class_weights("Sentiment", combined_sentiment)
# Out:
# Aspect distribution:
#   Class 0: 579 (4.85%)
#   Class 1: 344 (2.88%)
#   Class 2: 809 (6.77%)
#   Class 3: 1894 (15.86%)
#   Class 4: 2399 (20.09%)
#   Class 5: 3294 (27.58%)
#   Class 6: 624 (5.22%)
#   Class 7: 2001 (16.75%)
# Aspect weights: [2.579 4.34  1.845 0.788 0.622 0.453 2.393 0.746]
#
# Sentiment distribution:
#   Class 0: 6488 (54.32%)
#   Class 1: 885 (7.41%)
#   Class 2: 2001 (16.75%)
#   Class 3: 2570 (21.52%)
# Sentiment weights: [0.46  3.374 1.492 1.162]

# %%
df.head()
# Out:
#                                                 text aspect_1 aspect_2  \
# 0  TÒA ĐÃ TUYÊN PHẠT BỐ RUỘT 6 NĂM TÙ   Bị cáo và...      Law    Other
# 1  TÒA ĐÃ TUYÊN PHẠT BỐ RUỘT 6 NĂM TÙ   Bị cáo và...      Law    Other
# 2  TÒA ĐÃ TUYÊN PHẠT BỐ RUỘT 6 NĂM TÙ   Bị cáo và...      Law   Health
# 3  TÒA ĐÃ TUYÊN PHẠT BỐ RUỘT 6 NĂM TÙ   Bị cáo và...      Law   Health
# 4  TÒA ĐÃ TUYÊN PHẠT BỐ RUỘT 6 NĂM TÙ   Bị cáo và...      Law    Other
#
#   sentiment_1 sentiment_2  aspect_1_enc  aspect_2_enc  sentiment_1_enc  \
# 0    negative    negative             4             5                0
# 1    negative    negative             4             5                0
# 2    negative    negative             4             3                0
# 3    negative    negative             4             3                0
# 4    negative    negative             4             5                0
#
#    sentiment_2_enc
# 0                0
# 1                0
# 2                0
# 3                0
# 4                0

# %%
texts = df["text"].tolist()

y_aspect = df[["aspect_1_enc", "aspect_2_enc"]].values
y_sentiment = df[["sentiment_1_enc", "sentiment_2_enc"]].values

texts_temp, texts_test, y_a_temp, y_a_test, y_s_temp, y_s_test = train_test_split(
    texts, y_aspect, y_sentiment, test_size=0.1, random_state=42
)

texts_train, texts_val, y_a_train, y_a_val, y_s_train, y_s_val = train_test_split(
    texts_temp, y_a_temp, y_s_temp, test_size=0.2222, random_state=42
)

# %%
class MultiTaskClassifierWithEmbedding(nn.Module):
    def __init__(self, model_name, lstm_hidden_dim, lstm_layers, hidden_dims,
                 num_aspects, num_sentiments, task_specific_dims=None, device='cuda'):
        super().__init__()
        self.device = device
        
        # Load tokenizer + model embedding
        self.tokenizer = AutoTokenizer.from_pretrained(model_name)
        self.embedding_model = AutoModel.from_pretrained(model_name, trust_remote_code=True)
        self.embedding_model.to(device)
        self.embedding_model.eval()
        for p in self.embedding_model.parameters():
            p.requires_grad = False

        input_dim = self.embedding_model.config.hidden_size  # e.g., 1024

        # BiLSTM
        self.bilstm = nn.LSTM(
            input_size=input_dim,
            hidden_size=lstm_hidden_dim,
            num_layers=lstm_layers,
            batch_first=True,
            bidirectional=True
        )

        # Shared layers
        prev_dim = lstm_hidden_dim * 2
        layers = []
        for hdim in hidden_dims:
            layers += [
                nn.Linear(prev_dim, hdim),
                nn.ReLU(),
                nn.Dropout(0.3),
                nn.BatchNorm1d(hdim)
            ]
            prev_dim = hdim
        self.shared = nn.Sequential(*layers)

        if task_specific_dims is None:
            task_specific_dims = [prev_dim // 2, prev_dim // 4]

        self.aspect_1_layers = self._create_task_head(prev_dim, task_specific_dims, num_aspects)
        self.aspect_2_layers = self._create_task_head(prev_dim, task_specific_dims, num_aspects)
        self.sentiment_1_layers = self._create_task_head(prev_dim, task_specific_dims, num_sentiments)
        self.sentiment_2_layers = self._create_task_head(prev_dim, task_specific_dims, num_sentiments)

    def _create_task_head(self, input_dim, hidden_dims, output_dim):
        layers = []
        prev_dim = input_dim
        for hdim in hidden_dims:
            layers += [nn.Linear(prev_dim, hdim), nn.ReLU(), nn.Dropout(0.2)]
            prev_dim = hdim
        layers.append(nn.Linear(prev_dim, output_dim))
        return nn.Sequential(*layers)

    def forward(self, text_batch):
        """
        text_batch: List[str] — batch các câu
        """
        with torch.no_grad():
            inputs = self.tokenizer(text_batch, return_tensors='pt',
                                    truncation=True, padding='max_length', max_length=512)
            inputs = {k: v.to(self.device) for k, v in inputs.items()}
            outputs = self.embedding_model(**inputs)
            embeddings = outputs.last_hidden_state  # (B, T, D)

        embeddings = embeddings.to(torch.float32) 
        lstm_out, _ = self.bilstm(embeddings)
        pooled = torch.mean(lstm_out, dim=1)  # (B, 2H)

        shared_features = self.shared(pooled)

        a1 = self.aspect_1_layers(shared_features)
        a2 = self.aspect_2_layers(shared_features)
        s1 = self.sentiment_1_layers(shared_features)
        s2 = self.sentiment_2_layers(shared_features)

        return a1, a2, s1, s2

# %%
class Trainer:
    def __init__(self, model, train_data, val_data, device='cuda',
                 lr=1e-3, batch_size=64, num_epochs=10, step_size=10, gamma=0.5,
                 class_weights=None):
        self.model = model.to(device)
        self.train_texts, self.train_y_a, self.train_y_s = train_data
        self.val_texts, self.val_y_a, self.val_y_s = val_data
        self.device = device
        self.lr = lr
        self.batch_size = batch_size
        self.num_epochs = num_epochs

        self.optimizer = torch.optim.Adam(self.model.parameters(), lr=self.lr)
        self.scheduler = torch.optim.lr_scheduler.StepLR(self.optimizer, step_size=step_size, gamma=gamma)

        self.ce_a1 = nn.CrossEntropyLoss(weight=class_weights['a1'].to(device) if class_weights and 'a1' in class_weights else None)
        self.ce_a2 = nn.CrossEntropyLoss(weight=class_weights['a2'].to(device) if class_weights and 'a2' in class_weights else None)
        self.ce_s1 = nn.CrossEntropyLoss(weight=class_weights['s1'].to(device) if class_weights and 's1' in class_weights else None)
        self.ce_s2 = nn.CrossEntropyLoss(weight=class_weights['s2'].to(device) if class_weights and 's2' in class_weights else None)

    def get_batches(self, texts, y_aspect, y_sentiment):
        n = len(texts)
        for i in range(0, n, self.batch_size):
            yield (
                texts[i:i+self.batch_size],
                torch.tensor(y_aspect[i:i+self.batch_size], dtype=torch.long),
                torch.tensor(y_sentiment[i:i+self.batch_size], dtype=torch.long)
            )

    def train_epoch(self):
        self.model.train()
        total_loss = 0
        total_batches = 0

        for text_batch, yb_a, yb_s in self.get_batches(self.train_texts, self.train_y_a, self.train_y_s):
            yb_a = yb_a.to(self.device)
            yb_s = yb_s.to(self.device)

            self.optimizer.zero_grad()
            out_a1, out_a2, out_s1, out_s2 = self.model(text_batch)

            loss_a1 = self.ce_a1(out_a1, yb_a[:, 0])
            loss_a2 = self.ce_a2(out_a2, yb_a[:, 1])
            loss_s1 = self.ce_s1(out_s1, yb_s[:, 0])
            loss_s2 = self.ce_s2(out_s2, yb_s[:, 1])

            loss = loss_a1 + loss_a2 + loss_s1 + loss_s2
            loss.backward()
            self.optimizer.step()

            total_loss += loss.item()
            total_batches += 1

        return total_loss / total_batches

    def eval_epoch(self):
        self.model.eval()
        total_loss = 0
        total_batches = 0
        y_true_a1, y_pred_a1 = [], []
        y_true_a2, y_pred_a2 = [], []
        y_true_s1, y_pred_s1 = [], []
        y_true_s2, y_pred_s2 = [], []

        with torch.no_grad():
            for text_batch, yb_a, yb_s in self.get_batches(self.val_texts, self.val_y_a, self.val_y_s):
                yb_a = yb_a.to(self.device)
                yb_s = yb_s.to(self.device)

                out_a1, out_a2, out_s1, out_s2 = self.model(text_batch)

                loss_a1 = self.ce_a1(out_a1, yb_a[:, 0])
                loss_a2 = self.ce_a2(out_a2, yb_a[:, 1])
                loss_s1 = self.ce_s1(out_s1, yb_s[:, 0])
                loss_s2 = self.ce_s2(out_s2, yb_s[:, 1])

                loss = loss_a1 + loss_a2 + loss_s1 + loss_s2
                total_loss += loss.item()
                total_batches += 1

                y_true_a1 += yb_a[:, 0].cpu().tolist()
                y_pred_a1 += out_a1.argmax(dim=1).cpu().tolist()
                y_true_a2 += yb_a[:, 1].cpu().tolist()
                y_pred_a2 += out_a2.argmax(dim=1).cpu().tolist()
                y_true_s1 += yb_s[:, 0].cpu().tolist()
                y_pred_s1 += out_s1.argmax(dim=1).cpu().tolist()
                y_true_s2 += yb_s[:, 1].cpu().tolist()
                y_pred_s2 += out_s2.argmax(dim=1).cpu().tolist()

        f1_a1 = f1_score(y_true_a1, y_pred_a1, average="macro")
        f1_a2 = f1_score(y_true_a2, y_pred_a2, average="macro")
        f1_s1 = f1_score(y_true_s1, y_pred_s1, average="macro")
        f1_s2 = f1_score(y_true_s2, y_pred_s2, average="macro")
        avg_f1 = (f1_a1 + f1_a2 + f1_s1 + f1_s2) / 4

        print(f"F1 Scores — Aspect1: {f1_a1:.4f}, Aspect2: {f1_a2:.4f}, Sent1: {f1_s1:.4f}, Sent2: {f1_s2:.4f} | Avg: {avg_f1:.4f}")
        return total_loss / total_batches

    def train(self):
        for epoch in range(1, self.num_epochs + 1):
            train_loss = self.train_epoch()
            val_loss = self.eval_epoch()
            self.scheduler.step()

            current_lr = self.scheduler.get_last_lr()[0]
            print(f"Epoch {epoch}/{self.num_epochs} | LR: {current_lr:.6f} | Train Loss: {train_loss:.4f} | Val Loss: {val_loss:.4f}")

# %%
def get_batch(X, y_a, y_s, batch_size):
    for i in range(0, len(X), batch_size):
        yield X[i:i+batch_size], y_a[i:i+batch_size], y_s[i:i+batch_size]

# %%
num_aspects = len(aspect_encoder.classes_)
num_sentiments = len(sentiment_encoder.classes_)

# %%
device = "cuda" if torch.cuda.is_available() else "cpu"

# %%
train_data = (texts_train, y_a_train, y_s_train)
val_data = (texts_val, y_a_val, y_s_val)

# %%
model = MultiTaskClassifierWithEmbedding(
    model_name="jinaai/jina-embeddings-v3",
    lstm_hidden_dim=256,
    lstm_layers=3,
    hidden_dims=[1024, 512, 256, 128],
    num_aspects=num_aspects,
    num_sentiments=num_sentiments,
    task_specific_dims=[128, 64, 32],
    device=device
)

trainer = Trainer(
    model=model,
    train_data=train_data,
    val_data=val_data,
    device=device,
    lr=4e-3,
    batch_size=32,
    num_epochs=100,
    step_size=10,
    gamma=0.75,
    class_weights={
        'a1': w_aspect,
        'a2': w_aspect,
        's1': w_sentiment,
        's2': w_sentiment
    }
)
# Out:
# tokenizer_config.json: 0.00B [00:00, ?B/s]
# tokenizer.json:   0%|          | 0.00/17.1M [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/964 [00:00<?, ?B/s]
# config.json: 0.00B [00:00, ?B/s]
# configuration_xlm_roberta.py: 0.00B [00:00, ?B/s]
# A new version of the following files was downloaded from https://huggingface.co/jinaai/xlm-roberta-flash-implementation:
# - configuration_xlm_roberta.py
# . Make sure to double-check they do not contain any added malicious code. To avoid downloading new versions of the code file, you can pin a revision.
# modeling_lora.py: 0.00B [00:00, ?B/s]
# modeling_xlm_roberta.py: 0.00B [00:00, ?B/s]
# block.py: 0.00B [00:00, ?B/s]
# stochastic_depth.py: 0.00B [00:00, ?B/s]
# A new version of the following files was downloaded from https://huggingface.co/jinaai/xlm-roberta-flash-implementation:
# - stochastic_depth.py
# . Make sure to double-check they do not contain any added malicious code. To avoid downloading new versions of the code file, you can pin a revision.
# mha.py: 0.00B [00:00, ?B/s]
# rotary.py: 0.00B [00:00, ?B/s]
# A new version of the following files was downloaded from https://huggingface.co/jinaai/xlm-roberta-flash-implementation:
# - rotary.py
# . Make sure to double-check they do not contain any added malicious code. To avoid downloading new versions of the code file, you can pin a revision.
# A new version of the following files was downloaded from https://huggingface.co/jinaai/xlm-roberta-flash-implementation:
# - mha.py
# - rotary.py
# . Make sure to double-check they do not contain any added malicious code. To avoid downloading new versions of the code file, you can pin a revision.
# mlp.py: 0.00B [00:00, ?B/s]
# A new version of the following files was downloaded from https://huggingface.co/jinaai/xlm-roberta-flash-implementation:
# - mlp.py
# . Make sure to double-check they do not contain any added malicious code. To avoid downloading new versions of the code file, you can pin a revision.
# A new version of the following files was downloaded from https://huggingface.co/jinaai/xlm-roberta-flash-implementation:
# - block.py
# - stochastic_depth.py
# - mha.py
# - mlp.py
# . Make sure to double-check they do not contain any added malicious code. To avoid downloading new versions of the code file, you can pin a revision.
# embedding.py: 0.00B [00:00, ?B/s]
# A new version of the following files was downloaded from https://huggingface.co/jinaai/xlm-roberta-flash-implementation:
# - embedding.py
# . Make sure to double-check they do not contain any added malicious code. To avoid downloading new versions of the code file, you can pin a revision.
# xlm_padding.py: 0.00B [00:00, ?B/s]
# A new version of the following files was downloaded from https://huggingface.co/jinaai/xlm-roberta-flash-implementation:
# - xlm_padding.py
# . Make sure to double-check they do not contain any added malicious code. To avoid downloading new versions of the code file, you can pin a revision.
# A new version of the following files was downloaded from https://huggingface.co/jinaai/xlm-roberta-flash-implementation:
# - modeling_xlm_roberta.py
# - block.py
# - embedding.py
# - xlm_padding.py
# . Make sure to double-check they do not contain any added malicious code. To avoid downloading new versions of the code file, you can pin a revision.
# A new version of the following files was downloaded from https://huggingface.co/jinaai/xlm-roberta-flash-implementation:
# - modeling_lora.py
# - modeling_xlm_roberta.py
# . Make sure to double-check they do not contain any added malicious code. To avoid downloading new versions of the code file, you can pin a revision.
# 2025-07-13 13:19:59.342602: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1752412799.549073      19 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1752412799.608858      19 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# model.safetensors:   0%|          | 0.00/1.14G [00:00<?, ?B/s]

# %%
trainer.train()
# Out:
# F1 Scores — Aspect1: 0.0227, Aspect2: 0.0615, Sent1: 0.1576, Sent2: 0.1230 | Avg: 0.0912
# Epoch 1/100 | LR: 0.004000 | Train Loss: 6.2997 | Val Loss: 6.2562
# F1 Scores — Aspect1: 0.1339, Aspect2: 0.1307, Sent1: 0.4351, Sent2: 0.3403 | Avg: 0.2600
# Epoch 2/100 | LR: 0.004000 | Train Loss: 6.0565 | Val Loss: 5.6021
# F1 Scores — Aspect1: 0.2715, Aspect2: 0.1353, Sent1: 0.4368, Sent2: 0.3256 | Avg: 0.2923
# Epoch 3/100 | LR: 0.004000 | Train Loss: 5.4652 | Val Loss: 5.1661
# F1 Scores — Aspect1: 0.2720, Aspect2: 0.1613, Sent1: 0.4196, Sent2: 0.2581 | Avg: 0.2778
# Epoch 4/100 | LR: 0.004000 | Train Loss: 5.2969 | Val Loss: 4.9826
# F1 Scores — Aspect1: 0.1909, Aspect2: 0.1451, Sent1: 0.4411, Sent2: 0.3104 | Avg: 0.2719
# Epoch 5/100 | LR: 0.004000 | Train Loss: 5.1967 | Val Loss: 5.4198
# F1 Scores — Aspect1: 0.2906, Aspect2: 0.1855, Sent1: 0.4479, Sent2: 0.3273 | Avg: 0.3128
# Epoch 6/100 | LR: 0.004000 | Train Loss: 5.1634 | Val Loss: 4.9870
# F1 Scores — Aspect1: 0.3049, Aspect2: 0.1389, Sent1: 0.4302, Sent2: 0.3292 | Avg: 0.3008
# Epoch 7/100 | LR: 0.004000 | Train Loss: 5.1041 | Val Loss: 6.0356
# F1 Scores — Aspect1: 0.1496, Aspect2: 0.1617, Sent1: 0.4422, Sent2: 0.3362 | Avg: 0.2724
# Epoch 8/100 | LR: 0.004000 | Train Loss: 5.0437 | Val Loss: 172.7763
# F1 Scores — Aspect1: 0.0217, Aspect2: 0.0435, Sent1: 0.2564, Sent2: 0.2733 | Avg: 0.1487
# Epoch 9/100 | LR: 0.004000 | Train Loss: 5.0617 | Val Loss: 1466.9414
# F1 Scores — Aspect1: 0.0381, Aspect2: 0.0325, Sent1: 0.2699, Sent2: 0.1785 | Avg: 0.1297
# Epoch 10/100 | LR: 0.003000 | Train Loss: 5.0282 | Val Loss: 1706.3173
# F1 Scores — Aspect1: 0.2307, Aspect2: 0.1321, Sent1: 0.4110, Sent2: 0.2839 | Avg: 0.2644
# Epoch 11/100 | LR: 0.003000 | Train Loss: 4.9461 | Val Loss: 5.2784
# F1 Scores — Aspect1: 0.3039, Aspect2: 0.1832, Sent1: 0.4286, Sent2: 0.3287 | Avg: 0.3111
# Epoch 12/100 | LR: 0.003000 | Train Loss: 4.8958 | Val Loss: 4.8087
# F1 Scores — Aspect1: 0.3311, Aspect2: 0.1836, Sent1: 0.4182, Sent2: 0.3320 | Avg: 0.3162
# Epoch 13/100 | LR: 0.003000 | Train Loss: 4.8745 | Val Loss: 4.7784
# F1 Scores — Aspect1: 0.3105, Aspect2: 0.1786, Sent1: 0.4507, Sent2: 0.3164 | Avg: 0.3140
# Epoch 14/100 | LR: 0.003000 | Train Loss: 4.8437 | Val Loss: 4.8492
# F1 Scores — Aspect1: 0.3114, Aspect2: 0.2042, Sent1: 0.4176, Sent2: 0.3279 | Avg: 0.3153
# Epoch 15/100 | LR: 0.003000 | Train Loss: 4.8813 | Val Loss: 4.8487
# F1 Scores — Aspect1: 0.3394, Aspect2: 0.1956, Sent1: 0.4441, Sent2: 0.3353 | Avg: 0.3286
# Epoch 16/100 | LR: 0.003000 | Train Loss: 4.8376 | Val Loss: 4.7919
# F1 Scores — Aspect1: 0.2867, Aspect2: 0.1878, Sent1: 0.4014, Sent2: 0.3012 | Avg: 0.2943
# Epoch 17/100 | LR: 0.003000 | Train Loss: 4.9088 | Val Loss: 5.0392
# F1 Scores — Aspect1: 0.3233, Aspect2: 0.2076, Sent1: 0.4251, Sent2: 0.3313 | Avg: 0.3218
# Epoch 18/100 | LR: 0.003000 | Train Loss: 4.8757 | Val Loss: 4.7701
# F1 Scores — Aspect1: 0.3223, Aspect2: 0.2122, Sent1: 0.4236, Sent2: 0.3312 | Avg: 0.3223
# Epoch 19/100 | LR: 0.003000 | Train Loss: 4.9116 | Val Loss: 4.8967
# F1 Scores — Aspect1: 0.3254, Aspect2: 0.1882, Sent1: 0.4411, Sent2: 0.3337 | Avg: 0.3221
# Epoch 20/100 | LR: 0.002250 | Train Loss: 4.8937 | Val Loss: 4.8170
# F1 Scores — Aspect1: 0.1895, Aspect2: 0.1697, Sent1: 0.4227, Sent2: 0.3233 | Avg: 0.2763
# Epoch 21/100 | LR: 0.002250 | Train Loss: 4.9972 | Val Loss: 5.1157
# F1 Scores — Aspect1: 0.3222, Aspect2: 0.2093, Sent1: 0.4163, Sent2: 0.3202 | Avg: 0.3170
# Epoch 22/100 | LR: 0.002250 | Train Loss: 4.8716 | Val Loss: 4.8214
# F1 Scores — Aspect1: 0.3362, Aspect2: 0.2068, Sent1: 0.4257, Sent2: 0.3242 | Avg: 0.3232
# Epoch 23/100 | LR: 0.002250 | Train Loss: 4.7703 | Val Loss: 4.7219
# F1 Scores — Aspect1: 0.2405, Aspect2: 0.2292, Sent1: 0.4250, Sent2: 0.3229 | Avg: 0.3044
# Epoch 24/100 | LR: 0.002250 | Train Loss: 4.7692 | Val Loss: 5.2083
# F1 Scores — Aspect1: 0.3411, Aspect2: 0.2333, Sent1: 0.4408, Sent2: 0.3308 | Avg: 0.3365
# Epoch 25/100 | LR: 0.002250 | Train Loss: 4.7658 | Val Loss: 4.7232
# F1 Scores — Aspect1: 0.3325, Aspect2: 0.2159, Sent1: 0.4305, Sent2: 0.3215 | Avg: 0.3251
# Epoch 26/100 | LR: 0.002250 | Train Loss: 4.7343 | Val Loss: 4.8241
# F1 Scores — Aspect1: 0.2983, Aspect2: 0.1299, Sent1: 0.4509, Sent2: 0.3045 | Avg: 0.2959
# Epoch 27/100 | LR: 0.002250 | Train Loss: 4.8055 | Val Loss: 80.9107
# F1 Scores — Aspect1: 0.2926, Aspect2: 0.2263, Sent1: 0.4063, Sent2: 0.3045 | Avg: 0.3074
# Epoch 28/100 | LR: 0.002250 | Train Loss: 4.7800 | Val Loss: 4.8207
# F1 Scores — Aspect1: 0.3465, Aspect2: 0.2352, Sent1: 0.4691, Sent2: 0.3720 | Avg: 0.3557
# Epoch 29/100 | LR: 0.002250 | Train Loss: 4.6994 | Val Loss: 4.7237
# F1 Scores — Aspect1: 0.3368, Aspect2: 0.2252, Sent1: 0.4703, Sent2: 0.3309 | Avg: 0.3408
# Epoch 30/100 | LR: 0.001688 | Train Loss: 4.7400 | Val Loss: 4.6571
# F1 Scores — Aspect1: 0.3332, Aspect2: 0.2115, Sent1: 0.4431, Sent2: 0.3735 | Avg: 0.3403
# Epoch 31/100 | LR: 0.001688 | Train Loss: 4.6578 | Val Loss: 4.6921
# F1 Scores — Aspect1: 0.2942, Aspect2: 0.2282, Sent1: 0.4662, Sent2: 0.4338 | Avg: 0.3556
# Epoch 32/100 | LR: 0.001688 | Train Loss: 4.6390 | Val Loss: 4.8091
# F1 Scores — Aspect1: 0.3083, Aspect2: 0.2182, Sent1: 0.4414, Sent2: 0.4134 | Avg: 0.3453
# Epoch 33/100 | LR: 0.001688 | Train Loss: 4.6350 | Val Loss: 4.8879
# F1 Scores — Aspect1: 0.3304, Aspect2: 0.2445, Sent1: 0.4512, Sent2: 0.3277 | Avg: 0.3385
# Epoch 34/100 | LR: 0.001688 | Train Loss: 4.6505 | Val Loss: 4.6974
# F1 Scores — Aspect1: 0.3447, Aspect2: 0.2259, Sent1: 0.4952, Sent2: 0.4378 | Avg: 0.3759
# Epoch 35/100 | LR: 0.001688 | Train Loss: 4.6763 | Val Loss: 4.8543
# F1 Scores — Aspect1: 0.3340, Aspect2: 0.2546, Sent1: 0.4594, Sent2: 0.4352 | Avg: 0.3708
# Epoch 36/100 | LR: 0.001688 | Train Loss: 4.5440 | Val Loss: 4.6546
# F1 Scores — Aspect1: 0.3502, Aspect2: 0.2468, Sent1: 0.4935, Sent2: 0.4135 | Avg: 0.3760
# Epoch 37/100 | LR: 0.001688 | Train Loss: 4.5585 | Val Loss: 4.5845
# F1 Scores — Aspect1: 0.3398, Aspect2: 0.2577, Sent1: 0.4785, Sent2: 0.4304 | Avg: 0.3766
# Epoch 38/100 | LR: 0.001688 | Train Loss: 4.5054 | Val Loss: 4.5733
# F1 Scores — Aspect1: 0.3379, Aspect2: 0.2550, Sent1: 0.5045, Sent2: 0.4304 | Avg: 0.3819
# Epoch 39/100 | LR: 0.001688 | Train Loss: 4.5269 | Val Loss: 4.5906
# F1 Scores — Aspect1: 0.3233, Aspect2: 0.2385, Sent1: 0.4598, Sent2: 0.4174 | Avg: 0.3598
# Epoch 40/100 | LR: 0.001266 | Train Loss: 4.5301 | Val Loss: 4.7136
# F1 Scores — Aspect1: 0.3366, Aspect2: 0.2280, Sent1: 0.4688, Sent2: 0.4222 | Avg: 0.3639
# Epoch 41/100 | LR: 0.001266 | Train Loss: 4.5173 | Val Loss: 4.6950
# F1 Scores — Aspect1: 0.3341, Aspect2: 0.2394, Sent1: 0.4503, Sent2: 0.4376 | Avg: 0.3654
# Epoch 42/100 | LR: 0.001266 | Train Loss: 4.4686 | Val Loss: 4.6318
# F1 Scores — Aspect1: 0.3384, Aspect2: 0.2457, Sent1: 0.4627, Sent2: 0.4416 | Avg: 0.3721
# Epoch 43/100 | LR: 0.001266 | Train Loss: 4.4484 | Val Loss: 4.5695
# F1 Scores — Aspect1: 0.3324, Aspect2: 0.2595, Sent1: 0.4759, Sent2: 0.4325 | Avg: 0.3751
# Epoch 44/100 | LR: 0.001266 | Train Loss: 4.4346 | Val Loss: 4.5422
# F1 Scores — Aspect1: 0.3382, Aspect2: 0.2666, Sent1: 0.4616, Sent2: 0.4314 | Avg: 0.3744
# Epoch 45/100 | LR: 0.001266 | Train Loss: 4.4160 | Val Loss: 4.5829
# F1 Scores — Aspect1: 0.4062, Aspect2: 0.2564, Sent1: 0.4697, Sent2: 0.4292 | Avg: 0.3904
# Epoch 46/100 | LR: 0.001266 | Train Loss: 4.4382 | Val Loss: 4.5453
# F1 Scores — Aspect1: 0.3420, Aspect2: 0.2295, Sent1: 0.4318, Sent2: 0.3914 | Avg: 0.3487
# Epoch 47/100 | LR: 0.001266 | Train Loss: 4.4482 | Val Loss: 4.7554
# F1 Scores — Aspect1: 0.3637, Aspect2: 0.2275, Sent1: 0.4894, Sent2: 0.4316 | Avg: 0.3781
# Epoch 48/100 | LR: 0.001266 | Train Loss: 4.4130 | Val Loss: 4.5587
# F1 Scores — Aspect1: 0.4075, Aspect2: 0.2330, Sent1: 0.4805, Sent2: 0.4276 | Avg: 0.3871
# Epoch 49/100 | LR: 0.001266 | Train Loss: 4.3721 | Val Loss: 4.5786
# F1 Scores — Aspect1: 0.3825, Aspect2: 0.2528, Sent1: 0.5345, Sent2: 0.4189 | Avg: 0.3972
# Epoch 50/100 | LR: 0.000949 | Train Loss: 4.3787 | Val Loss: 4.5280
# F1 Scores — Aspect1: 0.3922, Aspect2: 0.2475, Sent1: 0.5026, Sent2: 0.4454 | Avg: 0.3969
# Epoch 51/100 | LR: 0.000949 | Train Loss: 4.3176 | Val Loss: 4.4862
# F1 Scores — Aspect1: 0.3882, Aspect2: 0.2191, Sent1: 0.4712, Sent2: 0.4503 | Avg: 0.3822
# Epoch 52/100 | LR: 0.000949 | Train Loss: 4.2584 | Val Loss: 4.5058
# F1 Scores — Aspect1: 0.3952, Aspect2: 0.2602, Sent1: 0.4907, Sent2: 0.4664 | Avg: 0.4031
# Epoch 53/100 | LR: 0.000949 | Train Loss: 4.2509 | Val Loss: 4.4882
# F1 Scores — Aspect1: 0.4583, Aspect2: 0.2054, Sent1: 0.5437, Sent2: 0.4722 | Avg: 0.4199
# Epoch 54/100 | LR: 0.000949 | Train Loss: 4.2691 | Val Loss: 4.6116
# F1 Scores — Aspect1: 0.3897, Aspect2: 0.2180, Sent1: 0.4888, Sent2: 0.4493 | Avg: 0.3864
# Epoch 55/100 | LR: 0.000949 | Train Loss: 4.2751 | Val Loss: 4.5266
# F1 Scores — Aspect1: 0.3974, Aspect2: 0.2203, Sent1: 0.5419, Sent2: 0.4353 | Avg: 0.3988
# Epoch 56/100 | LR: 0.000949 | Train Loss: 4.2380 | Val Loss: 4.5284
# F1 Scores — Aspect1: 0.3696, Aspect2: 0.2243, Sent1: 0.5362, Sent2: 0.4576 | Avg: 0.3969
# Epoch 57/100 | LR: 0.000949 | Train Loss: 4.2098 | Val Loss: 4.5081
# F1 Scores — Aspect1: 0.4004, Aspect2: 0.2103, Sent1: 0.5377, Sent2: 0.4543 | Avg: 0.4007
# Epoch 58/100 | LR: 0.000949 | Train Loss: 4.1952 | Val Loss: 4.5397
# F1 Scores — Aspect1: 0.4158, Aspect2: 0.2365, Sent1: 0.5229, Sent2: 0.4237 | Avg: 0.3997
# Epoch 59/100 | LR: 0.000949 | Train Loss: 4.1476 | Val Loss: 4.6132
# F1 Scores — Aspect1: 0.4147, Aspect2: 0.2496, Sent1: 0.4977, Sent2: 0.4475 | Avg: 0.4024
# Epoch 60/100 | LR: 0.000712 | Train Loss: 4.1924 | Val Loss: 4.5373
# F1 Scores — Aspect1: 0.4062, Aspect2: 0.2460, Sent1: 0.5589, Sent2: 0.4564 | Avg: 0.4169
# Epoch 61/100 | LR: 0.000712 | Train Loss: 4.1268 | Val Loss: 4.4849
# F1 Scores — Aspect1: 0.4148, Aspect2: 0.2347, Sent1: 0.5460, Sent2: 0.4600 | Avg: 0.4139
# Epoch 62/100 | LR: 0.000712 | Train Loss: 4.1410 | Val Loss: 4.4841
# F1 Scores — Aspect1: 0.4482, Aspect2: 0.2401, Sent1: 0.5161, Sent2: 0.4303 | Avg: 0.4087
# Epoch 63/100 | LR: 0.000712 | Train Loss: 4.1055 | Val Loss: 4.5598
# F1 Scores — Aspect1: 0.4204, Aspect2: 0.2582, Sent1: 0.5579, Sent2: 0.4560 | Avg: 0.4231
# Epoch 64/100 | LR: 0.000712 | Train Loss: 4.1349 | Val Loss: 4.4610
# F1 Scores — Aspect1: 0.3974, Aspect2: 0.2500, Sent1: 0.5488, Sent2: 0.4484 | Avg: 0.4111
# Epoch 65/100 | LR: 0.000712 | Train Loss: 4.0883 | Val Loss: 4.4959
# F1 Scores — Aspect1: 0.3866, Aspect2: 0.2636, Sent1: 0.5575, Sent2: 0.4423 | Avg: 0.4125
# Epoch 66/100 | LR: 0.000712 | Train Loss: 4.1140 | Val Loss: 4.4398
# F1 Scores — Aspect1: 0.4107, Aspect2: 0.2419, Sent1: 0.5582, Sent2: 0.4517 | Avg: 0.4156
# Epoch 67/100 | LR: 0.000712 | Train Loss: 4.0727 | Val Loss: 4.4955
# F1 Scores — Aspect1: 0.4416, Aspect2: 0.2333, Sent1: 0.5616, Sent2: 0.4571 | Avg: 0.4234
# Epoch 68/100 | LR: 0.000712 | Train Loss: 4.0472 | Val Loss: 4.5218
# F1 Scores — Aspect1: 0.4053, Aspect2: 0.2215, Sent1: 0.5464, Sent2: 0.4486 | Avg: 0.4054
# Epoch 69/100 | LR: 0.000712 | Train Loss: 4.0680 | Val Loss: 4.5659
# F1 Scores — Aspect1: 0.4096, Aspect2: 0.2484, Sent1: 0.5746, Sent2: 0.4411 | Avg: 0.4185
# Epoch 70/100 | LR: 0.000534 | Train Loss: 4.0615 | Val Loss: 4.5292
# F1 Scores — Aspect1: 0.4507, Aspect2: 0.2617, Sent1: 0.5714, Sent2: 0.4493 | Avg: 0.4333
# Epoch 71/100 | LR: 0.000534 | Train Loss: 3.9995 | Val Loss: 4.5371
# F1 Scores — Aspect1: 0.4311, Aspect2: 0.2463, Sent1: 0.5712, Sent2: 0.4580 | Avg: 0.4266
# Epoch 72/100 | LR: 0.000534 | Train Loss: 3.9955 | Val Loss: 4.5139
# F1 Scores — Aspect1: 0.4102, Aspect2: 0.2629, Sent1: 0.5614, Sent2: 0.4375 | Avg: 0.4180
# Epoch 73/100 | LR: 0.000534 | Train Loss: 4.0169 | Val Loss: 4.5308
# F1 Scores — Aspect1: 0.4292, Aspect2: 0.2571, Sent1: 0.5705, Sent2: 0.4477 | Avg: 0.4261
# Epoch 74/100 | LR: 0.000534 | Train Loss: 4.0086 | Val Loss: 4.5516
# F1 Scores — Aspect1: 0.4333, Aspect2: 0.2767, Sent1: 0.5793, Sent2: 0.4617 | Avg: 0.4377
# Epoch 75/100 | LR: 0.000534 | Train Loss: 3.9519 | Val Loss: 4.4960
# F1 Scores — Aspect1: 0.4198, Aspect2: 0.2732, Sent1: 0.5802, Sent2: 0.4623 | Avg: 0.4339
# Epoch 76/100 | LR: 0.000534 | Train Loss: 3.9614 | Val Loss: 4.4288
# F1 Scores — Aspect1: 0.4350, Aspect2: 0.2631, Sent1: 0.5683, Sent2: 0.4556 | Avg: 0.4305
# Epoch 77/100 | LR: 0.000534 | Train Loss: 3.9666 | Val Loss: 4.5350
# F1 Scores — Aspect1: 0.4464, Aspect2: 0.2686, Sent1: 0.5808, Sent2: 0.4401 | Avg: 0.4340
# Epoch 78/100 | LR: 0.000534 | Train Loss: 3.9726 | Val Loss: 4.4829
# F1 Scores — Aspect1: 0.4244, Aspect2: 0.2744, Sent1: 0.5769, Sent2: 0.4748 | Avg: 0.4377
# Epoch 79/100 | LR: 0.000534 | Train Loss: 3.9672 | Val Loss: 4.4665
# F1 Scores — Aspect1: 0.4922, Aspect2: 0.2751, Sent1: 0.5795, Sent2: 0.4546 | Avg: 0.4503
# Epoch 80/100 | LR: 0.000400 | Train Loss: 3.9759 | Val Loss: 4.5788
# F1 Scores — Aspect1: 0.4506, Aspect2: 0.2837, Sent1: 0.5777, Sent2: 0.4487 | Avg: 0.4402
# Epoch 81/100 | LR: 0.000400 | Train Loss: 3.9300 | Val Loss: 4.4846
# F1 Scores — Aspect1: 0.4923, Aspect2: 0.2758, Sent1: 0.5828, Sent2: 0.4554 | Avg: 0.4516
# Epoch 82/100 | LR: 0.000400 | Train Loss: 3.9016 | Val Loss: 4.5054
# F1 Scores — Aspect1: 0.4679, Aspect2: 0.2651, Sent1: 0.5763, Sent2: 0.4588 | Avg: 0.4420
# Epoch 83/100 | LR: 0.000400 | Train Loss: 3.9137 | Val Loss: 4.5416
# F1 Scores — Aspect1: 0.4756, Aspect2: 0.2784, Sent1: 0.5814, Sent2: 0.4527 | Avg: 0.4471
# Epoch 84/100 | LR: 0.000400 | Train Loss: 3.8758 | Val Loss: 4.5504
# F1 Scores — Aspect1: 0.4363, Aspect2: 0.2750, Sent1: 0.5697, Sent2: 0.4620 | Avg: 0.4358
# Epoch 85/100 | LR: 0.000400 | Train Loss: 3.8973 | Val Loss: 4.5014
# F1 Scores — Aspect1: 0.4882, Aspect2: 0.2764, Sent1: 0.5787, Sent2: 0.4585 | Avg: 0.4505
# Epoch 86/100 | LR: 0.000400 | Train Loss: 3.8422 | Val Loss: 4.5221
# F1 Scores — Aspect1: 0.4913, Aspect2: 0.2777, Sent1: 0.5761, Sent2: 0.4582 | Avg: 0.4508
# Epoch 87/100 | LR: 0.000400 | Train Loss: 3.8731 | Val Loss: 4.4209
# F1 Scores — Aspect1: 0.4859, Aspect2: 0.2734, Sent1: 0.5868, Sent2: 0.4576 | Avg: 0.4509
# Epoch 88/100 | LR: 0.000400 | Train Loss: 3.8314 | Val Loss: 4.4810
# F1 Scores — Aspect1: 0.5262, Aspect2: 0.2788, Sent1: 0.5747, Sent2: 0.4575 | Avg: 0.4593
# Epoch 89/100 | LR: 0.000400 | Train Loss: 3.8503 | Val Loss: 4.5110
# F1 Scores — Aspect1: 0.4882, Aspect2: 0.2769, Sent1: 0.5738, Sent2: 0.4571 | Avg: 0.4490
# Epoch 90/100 | LR: 0.000300 | Train Loss: 3.8731 | Val Loss: 4.5252
# F1 Scores — Aspect1: 0.4873, Aspect2: 0.2834, Sent1: 0.5735, Sent2: 0.4602 | Avg: 0.4511
# Epoch 91/100 | LR: 0.000300 | Train Loss: 3.8514 | Val Loss: 4.5296
# F1 Scores — Aspect1: 0.5022, Aspect2: 0.2745, Sent1: 0.5766, Sent2: 0.4598 | Avg: 0.4533
# Epoch 92/100 | LR: 0.000300 | Train Loss: 3.8418 | Val Loss: 4.5264
# F1 Scores — Aspect1: 0.4799, Aspect2: 0.2807, Sent1: 0.5867, Sent2: 0.4634 | Avg: 0.4527
# Epoch 93/100 | LR: 0.000300 | Train Loss: 3.8084 | Val Loss: 4.4842
# F1 Scores — Aspect1: 0.5025, Aspect2: 0.2827, Sent1: 0.5827, Sent2: 0.4682 | Avg: 0.4590
# Epoch 94/100 | LR: 0.000300 | Train Loss: 3.8306 | Val Loss: 4.4446
# F1 Scores — Aspect1: 0.4854, Aspect2: 0.2776, Sent1: 0.5892, Sent2: 0.4573 | Avg: 0.4524
# Epoch 95/100 | LR: 0.000300 | Train Loss: 3.7963 | Val Loss: 4.4783
# F1 Scores — Aspect1: 0.5087, Aspect2: 0.2758, Sent1: 0.5819, Sent2: 0.4523 | Avg: 0.4547
# Epoch 96/100 | LR: 0.000300 | Train Loss: 3.8229 | Val Loss: 4.4736
# F1 Scores — Aspect1: 0.5390, Aspect2: 0.2774, Sent1: 0.5876, Sent2: 0.4600 | Avg: 0.4660
# Epoch 97/100 | LR: 0.000300 | Train Loss: 3.7722 | Val Loss: 4.4329
# F1 Scores — Aspect1: 0.5367, Aspect2: 0.2779, Sent1: 0.5848, Sent2: 0.4569 | Avg: 0.4641
# Epoch 98/100 | LR: 0.000300 | Train Loss: 3.7972 | Val Loss: 4.5334
# F1 Scores — Aspect1: 0.5083, Aspect2: 0.2663, Sent1: 0.5899, Sent2: 0.4658 | Avg: 0.4576
# Epoch 99/100 | LR: 0.000300 | Train Loss: 3.7642 | Val Loss: 4.5693
# F1 Scores — Aspect1: 0.5394, Aspect2: 0.2737, Sent1: 0.5924, Sent2: 0.4631 | Avg: 0.4671
# Epoch 100/100 | LR: 0.000225 | Train Loss: 3.8079 | Val Loss: 4.5323

# %%
from sklearn.metrics import classification_report

def evaluate_on_test(model, test_data, batch_size=8, device='cuda'):
    model.eval()
    texts, y_a, y_s = test_data

    y_true_a1, y_pred_a1 = [], []
    y_true_a2, y_pred_a2 = [], []
    y_true_s1, y_pred_s1 = [], []
    y_true_s2, y_pred_s2 = [], []

    with torch.no_grad():
        for i in range(0, len(texts), batch_size):
            batch_texts = texts[i:i+batch_size]
            batch_y_a = torch.tensor(y_a[i:i+batch_size], dtype=torch.long).to(device)
            batch_y_s = torch.tensor(y_s[i:i+batch_size], dtype=torch.long).to(device)

            # Gọi forward với batch text (model tự tokenize & nhúng)
            out_a1, out_a2, out_s1, out_s2 = model(batch_texts)

            y_true_a1 += batch_y_a[:, 0].cpu().tolist()
            y_pred_a1 += out_a1.argmax(dim=1).cpu().tolist()
            y_true_a2 += batch_y_a[:, 1].cpu().tolist()
            y_pred_a2 += out_a2.argmax(dim=1).cpu().tolist()
            y_true_s1 += batch_y_s[:, 0].cpu().tolist()
            y_pred_s1 += out_s1.argmax(dim=1).cpu().tolist()
            y_true_s2 += batch_y_s[:, 1].cpu().tolist()
            y_pred_s2 += out_s2.argmax(dim=1).cpu().tolist()

    print("\n--- Test Evaluation ---")
    print("Aspect 1:")
    print(classification_report(y_true_a1, y_pred_a1, digits=4))
    print("Aspect 2:")
    print(classification_report(y_true_a2, y_pred_a2, digits=4))
    print("Sentiment 1:")
    print(classification_report(y_true_s1, y_pred_s1, digits=4))
    print("Sentiment 2:")
    print(classification_report(y_true_s2, y_pred_s2, digits=4))

# %%
evaluate_on_test(model, (texts_test, y_a_test, y_s_test), batch_size=8, device=device)
# Out:
# --- Test Evaluation ---
# Aspect 1:
#               precision    recall  f1-score   support
#
#            0     0.4583    0.9429    0.6168        35
#            1     0.4423    0.6765    0.5349        34
#            2     0.3367    0.6600    0.4459        50
#            3     0.2857    0.0154    0.0292       130
#            4     0.5582    0.7514    0.6406       185
#            5     0.5857    0.3832    0.4633       107
#            6     1.0000    0.8772    0.9346        57
#
#     accuracy                         0.5368       598
#    macro avg     0.5239    0.6152    0.5236       598
# weighted avg     0.5151    0.5368    0.4803       598
#
# Aspect 2:
#               precision    recall  f1-score   support
#
#            0     0.0000    0.0000    0.0000         9
#            1     0.0909    0.4615    0.1519        13
#            2     0.3784    0.7568    0.5045        37
#            3     0.4286    0.5893    0.4962        56
#            4     0.0000    0.0000    0.0000        63
#            5     0.5586    0.3821    0.4538       212
#            6     0.0000    0.0000    0.0000         6
#            7     0.6186    0.7228    0.6667       202
#
#     accuracy                         0.4916       598
#    macro avg     0.2594    0.3641    0.2841       598
# weighted avg     0.4725    0.4916    0.4671       598
#
# Sentiment 1:
#               precision    recall  f1-score   support
#
#            0     0.9342    0.7263    0.8173       391
#            1     0.3125    0.2885    0.3000        52
#            3     0.5163    0.8194    0.6334       155
#
#     accuracy                         0.7124       598
#    macro avg     0.5877    0.6114    0.5836       598
# weighted avg     0.7718    0.7124    0.7246       598
#
# Sentiment 2:
#               precision    recall  f1-score   support
#
#            0     0.8317    0.6065    0.7015       277
#            1     0.0000    0.0000    0.0000        29
#            2     0.5621    0.8069    0.6626       202
#            3     0.4906    0.5778    0.5306        90
#
#     accuracy                         0.6405       598
#    macro avg     0.4711    0.4978    0.4737       598
# weighted avg     0.6489    0.6405    0.6286       598
# /usr/local/lib/python3.11/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.11/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.11/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.11/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.11/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.11/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %%
test_text = """Khoảnh khắc Quang Hùng MasterD "flex" sự học tiếng Hàn cấp tốc để giao lưu với anh Long. 
Fan boy này đi đu idol thành công quá rồi 🤣🤣 
Video: Phạm Thanh Hoa 
Gọi ộp pa thì đội tóc giả nữa a kkk"""

# %%
def predict(text):
    model.eval()
    with torch.no_grad():
        out_a1, out_a2, out_s1, out_s2 = model([text])  # Gói trong list vì batch size = 1

        pred_a1 = torch.argmax(out_a1, dim=1).item()
        pred_a2 = torch.argmax(out_a2, dim=1).item()
        pred_s1 = torch.argmax(out_s1, dim=1).item()
        pred_s2 = torch.argmax(out_s2, dim=1).item()

        aspect_1_label = aspect_encoder.inverse_transform([pred_a1])[0]
        aspect_2_label = aspect_encoder.inverse_transform([pred_a2])[0]
        sentiment_1_label = sentiment_encoder.inverse_transform([pred_s1])[0]
        sentiment_2_label = sentiment_encoder.inverse_transform([pred_s2])[0]

        print("=== PREDICTION RESULT ===")
        print(f"Aspect 1:    {aspect_1_label}")
        print(f"Sentiment 1: {sentiment_1_label}")
        print(f"Aspect 2:    {aspect_2_label}")
        print(f"Sentiment 2: {sentiment_2_label}")

# %%
predict(test_text)
# Out:
# === PREDICTION RESULT ===
# Aspect 1:    Art
# Sentiment 1: positive
# Aspect 2:    null
# Sentiment 2: null

# %%
import torch
import joblib
import os

os.makedirs("saved_model", exist_ok=True)

torch.save({
    'model_state_dict': model.state_dict(),
    'model_name': "jinaai/jina-embeddings-v3",
    'lstm_hidden_dim': 256,
    'lstm_layers': 3,
    'hidden_dims': [1024, 512, 256, 128],
    'task_specific_dims': [128, 64, 32],
    'num_aspects': num_aspects,
    'num_sentiments': num_sentiments
}, "saved_model/model.pt")

# Lưu encoder
joblib.dump(aspect_encoder, "saved_model/aspect_encoder.pkl")
joblib.dump(sentiment_encoder, "saved_model/sentiment_encoder.pkl")
# Out:
# ['saved_model/sentiment_encoder.pkl']
